# %% [markdown]
# ## Set Global Seed

# %%
import os
import random
import numpy as np
import torch
import transformers

def set_all_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
seed = 260615
set_all_seeds(seed)

print("The global seed " + str(seed))
# Out:
# The global seed 260615

# %% [markdown]
# ## Hyperparameters

# %%
# LANGUAGE

_LANGUAGE_         = 'en'
_DATASET_          = '2017'

# %%
# MODEL CLASSIFICATION

_PRETRAINED_LM_    = 'ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli'
_PREPROCESS_TEXT_  = True
_TWEET_BATCH_SIZE_ = 5
_ADAPTER_CONFIG_   = transformers.MAMConfig()
_MAX_SEQ_LEN_      = 150

# %%
# TRAIN

_OUTPUT_DIR_       = 'checkPointsMAMNLI'
_LOGGING_STEPS_    = 50
_NUM_AUTHORS_      = 512
_K_FOLD_CV_        = 5
_NO_GPUS_          = 1
_BATCH_SIZE_       = int(8 / _NO_GPUS_)
_EPOCHS_           = 10
_LEARNING_RATE_    = 1e-5

# PREDICTIONS

_PRED_DIR_         = 'MAMNLI'

# %% [markdown]
# ## Other parameters

# %%
# LABEL DICTONARIES -----------------------------------------------------------------------

# 2015

age_dict  = {'18-24': 0, '25-34': 1, '35-49': 2, '50-XX': 3}
ageEN_hyp = {0: '18-24', 1: '25-34', 2: '35-49', 3: '50-XX'}
ageES_hyp = {0: 'La edad de esta persona es entre 18 y 24 años', 
             1: 'La edad de esta persona es entre 25 y 34 años', 
             2: 'La edad de esta persona es entre 35 y 49 años', 
             3: 'La edad de esta persona es más de 50 años'}

# 2017

gender_dict    = {'female': 0, 'male':   1}
varietyEN_dict = {'australia': 0, 'canada': 1, 'great britain': 2, 'ireland': 3, 'new zealand': 4, 'united states': 5}
varietyES_dict = {'argentina': 0, 'chile': 1, 'colombia': 2, 'mexico': 3, 'peru': 4, 'spain': 5, 'venezuela': 6}  

genderEN_hyp  = {0: 'I’m a female', 1: 'I’m a male'}
genderES_hyp  = {0: 'Mi nombre es María', 1: 'Mi nombre es José'}

# 2019

bots_dict  = {'human': 0, 'bot': 1}
botsEN_hyp = {0: 'This is a text from a person', 1: 'This is a text from a machine'}
botsES_hyp = {0: 'Humano', 1: 'Bot'}

# 2020 

fakeNews_dict  = {'0': 0, '1': 1}
fakeNewsEN_hyp = {0: 'This author is a normal user', 1: 'This author spreads fake news'}
fakeNewsES_hyp = {0: 'Este autor es un usuario normal', 1: 'Este autor publica noticias falsas'}

# 2021

hateSpeech_dict  = {'0': 0, '1': 1}
hateSpeechEN_hyp = {0: 'This text does not contain hate speech', 1: 'This text expresses prejudice and hate speech'}
hateSpeechES_hyp = {0: 'Este texto es moderado, respetuoso, cortés y civilizado', 1: 'Este texto expresa odio o prejuicios'}

# %%
# SET LANGUAGE DICTIONARIES --------------------------------------------------

if _LANGUAGE_ == 'en':
    age_hyp        = ageEN_hyp
    gender_hyp     = genderEN_hyp
    variety_dict   = varietyEN_dict
    fakeNews_hyp   = fakeNewsEN_hyp
    hateSpeech_hyp = hateSpeechEN_hyp
    bots_hyp       = botsEN_hyp 

elif _LANGUAGE_ == 'es':
    age_hyp        = ageES_hyp
    gender_hyp     = genderES_hyp
    variety_dict   = varietyES_dict
    fakeNews_hyp   = fakeNewsES_hyp
    hateSpeech_hyp = hateSpeechES_hyp
    bots_hyp       = botsES_hyp
    
    
# SET LANGUAGE AND DATASET PARAMETERS ----------------------------------------
    
if   _DATASET_ == '2015':
    label_idx  = 2
    class_dict = age_dict
    label_name = 'age'
    label_hyp  = age_hyp
    
elif _DATASET_ == '2017':
    label_idx  = 1
    class_dict = gender_dict
    label_name = 'gender'
    label_hyp  = gender_hyp
    
elif _DATASET_ == '2019':
    label_idx  = 1
    class_dict = bots_dict
    label_name = 'bots'
    label_hyp  = bots_hyp
    
elif _DATASET_ == '2020':
    label_idx  = 1
    class_dict = fakeNews_dict
    label_name = 'fakeNews'
    label_hyp  = fakeNews_hyp
    
elif _DATASET_ == '2021':
    label_idx  = 1
    class_dict = hateSpeech_dict
    label_name = 'hateSpeech'
    label_hyp  = hateSpeech_hyp

# %%
from transformers import AutoTokenizer, PretrainedConfig

tokenizer = AutoTokenizer.from_pretrained(_PRETRAINED_LM_)
vocab = tokenizer.get_vocab()

config             = PretrainedConfig.from_pretrained(_PRETRAINED_LM_)
nli_label2id       = config.label2id
is_encoder_decoder = config.is_encoder_decoder
# Out:
# You are using a model of type bart to instantiate a model of type . This is not supported for all configurations of models and can yield errors.

# %% [markdown]
# ## Datasets

# %%
# GET AUTHORS AND LABELS -----------------------------------------------------

from tools.DataLoaders import BasePAN

baseTrain  = BasePAN(Dir        = 'data/' + _DATASET_,
                     split      = 'train',
                     language   = _LANGUAGE_,
                     label_idx  = label_idx,
                     class_dict = class_dict,
                     label_name = label_name)

baseTest   = BasePAN(Dir        = 'data/' + _DATASET_,
                     split      = 'test',
                     language   = _LANGUAGE_,
                     label_idx  = label_idx,
                     class_dict = class_dict,
                     label_name = label_name)

# %%
# GET K-FOLD SPLITS -----------------------------------------------------

crossVal_splits = baseTrain.cross_val(_K_FOLD_CV_, _NUM_AUTHORS_)

crossVal_splits[0][0]
# Out:
# ['5fb799c39e1c8a92f6c580ff516bdc',
#  'c3fc612f9fe498210613a7991a1c7f2a',
#  '7a2b6e351032615aa3c19d8c252bd552',
#  '5849edbc23ee81353911f951e0903ea',
#  '42dc691f860354271b77171b152967cf',
#  '7ffdaa0d7d70f8c485e3f645aa9ba7d9',
#  '49a6b94266d28dd3e241905d2300e504',
#  'ad6faf0d1624a7015f0eab10a6516fc2',
#  'c93fd1e3c9e5ba437a544db7b84e375e',
#  '5fc0d0a6f90891a3cb4b32d7169e6676',
#  '60705218ce29389bb7181837d701556e',
#  '56b4ff0baba162a5c53323fe3dcd0d64',
#  'a9430efa05e5abc56310ff9a5173cd07',
#  '87318fe9b132b934dd298c3f7f3fbcf6',
#  'd052413e23540da3e613f466e53a1317',
#  '1de5e53b813163d9c5105cd15ccaa842',
#  '4dbd49cb6fe542993bfd0b968be669bd',
#  'e9cd1a184a4c34f480748df1bd3d2bf6',
#  '505da57fd58bb00c6a164789c9658c58',
#  'b123667f9d6697eb2828dc00920099fc',
#  'b89bdf194952b1e65de3ba5d8cf35305',
#  '47a9df75b78c187edebc2a740b118dc8',
#  'ca3df92ea429b9664cc0c2dda9739235',
#  'ad0583fece5cfe395a495623976b7a69',
#  'aeb2e80618c635954b8c15c9f3d2e1d8',
#  '8ed8cb11745ebea846fd90368151ae04',
#  '854dd2af328428b9105d6a310deb331e',
#  '20647d1b6e6953e2b9135490fef1c2da',
#  'ca345e44f6c67182931cd66de0776f57',
#  '79c856daa8d4a8d207b3ff4883644c94',
#  'ac7b19d04760fe46783bf7edfadaa8c',
#  '716b8f255475f227e58d67a9dcd896d6',
#  'bd702beb4943e0437e738bb38d16b585',
#  '94ebd5a3f2817b2f03098b9f241518e',
#  '835a707182f1dba8a0672fcb03f7c8a9',
#  '4ab519abb222f9f4615e0a99cd990868',
#  '849a99517e0e1ee3b8e6adcbea476759',
#  '97159e619b8d88bdd837f7f7e738de43',
#  'ea4ba05c6502de432eaa778326fe247',
#  '73533c22ef5b8cc5e1cc4dfc06396b29',
#  '716a1d4d8e040774666d00fd64edc81c',
#  ...]

# %%
# GET TWEETS -----------------------------------------------------

baseTrain.get_all_data(_TWEET_BATCH_SIZE_, tokenizer, _MAX_SEQ_LEN_, _PREPROCESS_TEXT_, NLI=True, label_hyp=label_hyp, nli_label2id=nli_label2id)
# Out:
# Reading data...
#     Done
# Preprocessing text...
#     Done
# Tokenizing...
#     Done
# Merging data...
#     Done
#
# Total Instances: 144000

# %% [markdown]
# ## Training and Testing

# %%
from tools.DataLoaders import DatasetPANnli

baseTest.get_all_data(_TWEET_BATCH_SIZE_, tokenizer, _MAX_SEQ_LEN_, _PREPROCESS_TEXT_, NLI=True, label_hyp=label_hyp, nli_label2id=nli_label2id)

Test = DatasetPANnli(baseTest)
# Out:
# Reading data...
#     Done
# Preprocessing text...
#     Done
# Tokenizing...
#     Done
# Merging data...
#     Done
#
# Total Instances: 105600

# %%
from transformers import TrainingArguments

samples = 4 * _NUM_AUTHORS_ * int(100 / _TWEET_BATCH_SIZE_)
_LOGGING_STEPS_ = int(samples / _BATCH_SIZE_)

training_args = TrainingArguments(
    learning_rate               = _LEARNING_RATE_,
    num_train_epochs            = _EPOCHS_,
    per_device_train_batch_size = _BATCH_SIZE_,
    per_device_eval_batch_size  = 200,
    logging_steps               = _LOGGING_STEPS_,
    output_dir                  = _OUTPUT_DIR_,
    save_total_limit            = 5,
    overwrite_output_dir        = True,
    remove_unused_columns       = False,
)

# %%
from transformers import AutoAdapterModel, AutoModelForSequenceClassification
from tools.DataLoaders import DatasetCrossValnli
from transformers import AdapterTrainer
from tools.Testing import compute_author_predictions_nli, compute_author_predictions_nli_LR
from sklearn.metrics import f1_score, classification_report
import pickle


# train

task = label_name

f1s_soft = []
f1s_hard = []

f1s_soft_LR = []
f1s_hard_LR = []

for split in range( _K_FOLD_CV_ ):
    
    # loaders for current split ------------------------------------------
    
    authors_train, authors_val = crossVal_splits[split]
    
    Train = DatasetCrossValnli(baseTrain, authors_train)
    Val   = DatasetCrossValnli(baseTrain, authors_val)
    
    
    # initialize model ---------------------------------------------------
    

    static_head_model = AutoModelForSequenceClassification.from_pretrained(_PRETRAINED_LM_)
    static_head_model.add_adapter(task, config = _ADAPTER_CONFIG_) 
    static_head_model.save_adapter('aux_adapter_'+_PRED_DIR_, task)

    model = AutoAdapterModel.from_pretrained(_PRETRAINED_LM_)
    model.load_adapter('aux_adapter_'+_PRED_DIR_, load_as=task)
    #model.load_adapter('pretrained_adapter_NLI', load_as=task)

    model.set_active_adapters(task)
    model.train_adapter(task)


    # create trainer and train -------------------------------------------

    trainer = AdapterTrainer(
        model           = model,
        args            = training_args,
        train_dataset   = Train,
    )
    trainer.args._n_gpu = _NO_GPUS_

    trainer.train()
    
    
    # get predictions ----------------------------------------------------
    
    
    ignore_keys = None
    if is_encoder_decoder:
        ignore_keys = ['encoder_last_hidden_state']

    results            = trainer.predict(Test , ignore_keys = ignore_keys)
    author_predictions = compute_author_predictions_nli(baseTest, results.predictions, task, len(class_dict), nli_label2id)

    # report metrics 

    report = {'soft': classification_report(author_predictions['true'], author_predictions['pred_soft'], digits=4), 
               'hard': classification_report(author_predictions['true'], author_predictions['pred_hard'], digits=4)}

    f1s_soft.append( f1_score(author_predictions['true'], author_predictions['pred_soft'], average = 'macro') )
    f1s_hard.append( f1_score(author_predictions['true'], author_predictions['pred_hard'], average = 'macro') )
    
    print("Results with split " + str(split + 1) + ":\n")
    print("soft voting:\n", report['soft'], '\n')
    print("hard voting:\n", report['hard'])


    # get predictions with Logistic Regression----------------------------

    resultsTrain = trainer.predict(Train, ignore_keys = ignore_keys)
    author_predictions_LR = compute_author_predictions_nli_LR(Train, baseTest, resultsTrain.predictions, results.predictions, task, len(class_dict))
    
    f1s_soft_LR.append( f1_score(author_predictions_LR['true'], author_predictions_LR['pred_soft'], average = 'macro') )
    f1s_hard_LR.append( f1_score(author_predictions_LR['true'], author_predictions_LR['pred_hard'], average = 'macro') )
    
    # report metrics 

    report_LR = {'soft': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_soft'], digits=4), 
               'hard': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_hard'], digits=4)}

    print("Results with split " + str(split + 1) + " using LOGISTIC REGRESSION:\n")
    print("soft voting:\n", report_LR['soft'], '\n')
    print("hard voting:\n", report_LR['hard'])

     
    
    # save predictions ----------------------------------------------------
    
    DIR = 'results/' + _DATASET_ + '/' + _LANGUAGE_ + '/' + _PRED_DIR_ + '/' + str(_NUM_AUTHORS_) + '_authors/test_split_' + str(split + 1) + '/'
    if not os.path.exists(DIR):
        os.makedirs(DIR)

    with open(DIR + 'predictions.pickle', 'wb') as f:
        pickle.dump(author_predictions, f)
    
    with open(DIR + 'predictions_LR.pickle', 'wb') as f:
        pickle.dump(author_predictions_LR, f)

    with open(DIR + 'report.txt', 'w') as f:
        f.write("soft voting:\n" + report['soft'] + '\n\n')
        f.write("hard voting:\n" + report['hard'])
        
    with open(DIR + 'report_LR.txt', 'w') as f:
        f.write("soft voting:\n" + report_LR['soft'] + '\n\n')
        f.write("hard voting:\n" + report_LR['hard'])
# Out:
# Some weights of the model checkpoint at ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli were not used when initializing BartAdapterModel: ['classification_head.out_proj.bias', 'classification_head.dense.weight', 'classification_head.out_proj.weight', 'classification_head.dense.bias']
# - This IS expected if you are initializing BartAdapterModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BartAdapterModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /001/usuarios/isaac.bribiesca/anaconda3/envs/NLP/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 40960
#   Num Epochs = 10
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 51200
#     <div>
#
#       <progress value='24853' max='51200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [24853/51200 3:15:13 < 3:26:58, 2.12 it/s, Epoch 4.85/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5120</td>
#       <td>0.214800</td>
#     </tr>
#     <tr>
#       <td>10240</td>
#       <td>0.095800</td>
#     </tr>
#     <tr>
#       <td>15360</td>
#       <td>0.055200</td>
#     </tr>
#     <tr>
#       <td>20480</td>
#       <td>0.028200</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-500
# Configuration saved in checkPointsMAMNLI/checkpoint-500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-500/bots/pytorch_model_head.bin
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-1000
# Configuration saved in checkPointsMAMNLI/checkpoint-1000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-1000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-1000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1000/bots/pytorch_model_head.bin
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-1500
# Configuration saved in checkPointsMAMNLI/checkpoint-1500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-1500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-1500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1500/bots/pytorch_model_head.bin
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-2000
# Configuration saved in checkPointsMAMNLI/checkpoint-2000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-2000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-2000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2000/bots/pytorch_model_head.bin
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-2500
# Configuration saved in checkPointsMAMNLI/checkpoint-2500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-2500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-2500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2500/bots/pytorch_model_head.bin
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-3000
# Configuration saved in checkPointsMAMNLI/checkpoint-3000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-3000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-3000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-3500
# Configuration saved in checkPointsMAMNLI/checkpoint-3500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-3500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-3500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-4000
# Configuration saved in checkPointsMAMNLI/checkpoint-4000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-4000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-4000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-4500
# Configuration saved in checkPointsMAMNLI/checkpoint-4500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-4500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-4500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-5000
# Configuration saved in checkPointsMAMNLI/checkpoint-5000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-5000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-5000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-5500
# Configuration saved in checkPointsMAMNLI/checkpoint-5500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-5500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-5500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-6000
# Configuration saved in checkPointsMAMNLI/checkpoint-6000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-6000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-6000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-6500
# Configuration saved in checkPointsMAMNLI/checkpoint-6500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-6500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-6500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-7000
# Configuration saved in checkPointsMAMNLI/checkpoint-7000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-7000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-7000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-7500
# Configuration saved in checkPointsMAMNLI/checkpoint-7500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-7500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-7500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-8000
# Configuration saved in checkPointsMAMNLI/checkpoint-8000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-8000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-8000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-8000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-8000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-8000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-5500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-8500
# Configuration saved in checkPointsMAMNLI/checkpoint-8500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-8500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-8500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-8500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-8500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-8500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-9000
# Configuration saved in checkPointsMAMNLI/checkpoint-9000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-9000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-9000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-9000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-9000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-9000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-9500
# Configuration saved in checkPointsMAMNLI/checkpoint-9500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-9500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-9500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-9500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-9500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-9500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-10000
# Configuration saved in checkPointsMAMNLI/checkpoint-10000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-10000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-10000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-10000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-10000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-10000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-10500
# Configuration saved in checkPointsMAMNLI/checkpoint-10500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-10500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-10500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-10500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-10500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-10500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-11000
# Configuration saved in checkPointsMAMNLI/checkpoint-11000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-11000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-11000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-11000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-11000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-11000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-8500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-11500
# Configuration saved in checkPointsMAMNLI/checkpoint-11500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-11500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-11500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-11500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-11500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-11500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-12000
# Configuration saved in checkPointsMAMNLI/checkpoint-12000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-12000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-12000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-12000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-12000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-12000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-9500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-12500
# Configuration saved in checkPointsMAMNLI/checkpoint-12500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-12500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-12500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-12500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-12500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-12500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-10000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-13000
# Configuration saved in checkPointsMAMNLI/checkpoint-13000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-13000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-13000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-13000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-13000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-13000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-10500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-13500
# Configuration saved in checkPointsMAMNLI/checkpoint-13500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-13500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-13500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-13500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-13500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-13500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-11000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-14000
# Configuration saved in checkPointsMAMNLI/checkpoint-14000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-14000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-14000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-14000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-14000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-14000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-11500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-14500
# Configuration saved in checkPointsMAMNLI/checkpoint-14500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-14500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-14500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-14500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-14500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-14500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-12000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-15000
# Configuration saved in checkPointsMAMNLI/checkpoint-15000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-15000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-15000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-15000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-15000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-15000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-12500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-15500
# Configuration saved in checkPointsMAMNLI/checkpoint-15500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-15500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-15500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-15500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-15500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-15500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-13000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-16000
# Configuration saved in checkPointsMAMNLI/checkpoint-16000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-16000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-16000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-16000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-16000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-16000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-13500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-16500
# Configuration saved in checkPointsMAMNLI/checkpoint-16500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-16500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-16500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-16500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-16500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-16500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-14000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-17000
# Configuration saved in checkPointsMAMNLI/checkpoint-17000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-17000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-17000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-17000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-17000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-17000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-14500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-17500
# Configuration saved in checkPointsMAMNLI/checkpoint-17500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-17500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-17500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-17500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-17500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-17500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-15000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-18000
# Configuration saved in checkPointsMAMNLI/checkpoint-18000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-18000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-18000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-18000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-18000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-18000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-15500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-18500
# Configuration saved in checkPointsMAMNLI/checkpoint-18500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-18500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-18500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-18500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-18500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-18500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-16000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-19000
# Configuration saved in checkPointsMAMNLI/checkpoint-19000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-19000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-19000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-19000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-19000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-19000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-16500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-19500
# Configuration saved in checkPointsMAMNLI/checkpoint-19500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-19500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-19500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-19500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-19500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-19500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-17000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-20000
# Configuration saved in checkPointsMAMNLI/checkpoint-20000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-20000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-20000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-20000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-20000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-20000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-17500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-20500
# Configuration saved in checkPointsMAMNLI/checkpoint-20500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-20500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-20500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-20500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-20500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-20500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-18000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-21000
# Configuration saved in checkPointsMAMNLI/checkpoint-21000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-21000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-21000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-21000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-21000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-21000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-18500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-21500
# Configuration saved in checkPointsMAMNLI/checkpoint-21500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-21500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-21500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-21500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-21500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-21500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-19000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-22000
# Configuration saved in checkPointsMAMNLI/checkpoint-22000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-22000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-22000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-22000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-22000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-22000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-19500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-22500
# Configuration saved in checkPointsMAMNLI/checkpoint-22500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-22500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-22500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-22500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-22500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-22500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-20000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-23000
# Configuration saved in checkPointsMAMNLI/checkpoint-23000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-23000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-23000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-23000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-23000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-23000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-20500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-23500
# Configuration saved in checkPointsMAMNLI/checkpoint-23500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-23500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-23500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-23500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-23500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-23500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-21000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-24000
# Configuration saved in checkPointsMAMNLI/checkpoint-24000/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-24000/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-24000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-24000/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-24000/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-24000/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-21500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-24500
# Configuration saved in checkPointsMAMNLI/checkpoint-24500/bots/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-24500/bots/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-24500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-24500/bots/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-24500/bots/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-24500/bots/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-22000] due to args.save_total_limit

# %%
# report statistics

print('Soft results: ', f1s_soft)
print('\nHard results: ', f1s_hard)

f1s_soft = np.array(f1s_soft)
f1s_hard = np.array(f1s_hard)

FewShot_Results = {'soft': [f1s_soft.mean(), f1s_soft.std()], 'hard': [f1s_hard.mean(), f1s_hard.std()]}

print('\n\nSoft statistics: ')
print('\t[avg, std]:', FewShot_Results['soft'])

print('\nHard statistics: ')
print('\t[avg, std]:', FewShot_Results['hard'])
# Out:
# Soft results:  [0.9210544  0.92595958 0.92939467 0.92179717 0.91722352]
#
# Hard results:  [0.92217401 0.92630791 0.92709595 0.91948955 0.91491223]
#
#
# Soft statistics:
# 	[avg, std]: [0.9230858699504138, 0.00420033109152025]
#
# Hard statistics:
# 	[avg, std]: [0.9219959297392544, 0.004496573251959057]

# %%
# report statistics

print('Soft results: ', f1s_soft_LR)
print('\nHard results: ', f1s_hard_LR)

f1s_soft_LR = np.array(f1s_soft_LR)
f1s_hard_LR = np.array(f1s_hard_LR)

FewShot_Results_LR = {'soft': [f1s_soft_LR.mean(), f1s_soft_LR.std()], 'hard': [f1s_hard_LR.mean(), f1s_hard_LR.std()]}

print('\n\nSoft statistics with LOGISTIC REGRESSION: ')
print('\t[avg, std]:', FewShot_Results_LR['soft'])

print('\nHard statistics with LOGISTIC REGRESSION: ')
print('\t[avg, std]:', FewShot_Results_LR['hard'])
# Out:
# Soft results:  [0.92142585 0.92555416 0.93094071 0.91910665 0.91645781]
#
# Hard results:  [0.92216837 0.92401001 0.92901257 0.9190939  0.91376213]
#
#
# Soft statistics with LOGISTIC REGRESSION:
# 	[avg, std]: [0.9226970360266298, 0.005090305091236716]
#
# Hard statistics with LOGISTIC REGRESSION:
# 	[avg, std]: [0.921609395580299, 0.005075230525547022]

# %% [markdown]
# ## Training with all

# %%
from tools.DataLoaders import DatasetPANnli

baseTest.get_all_data(_TWEET_BATCH_SIZE_, tokenizer, _MAX_SEQ_LEN_, _PREPROCESS_TEXT_, NLI=True, label_hyp=label_hyp, nli_label2id=nli_label2id)

Test  = DatasetPANnli(baseTest)
Train = DatasetPANnli(baseTrain)
# Out:
# Reading data...
#     Done
# Preprocessing text...
#     Done
# Tokenizing...
#     Done
# Merging data...
#     Done
#
# Total Instances: 96000

# %%
from transformers import TrainingArguments

samples = 4 * _NUM_AUTHORS_ * int(100 / _TWEET_BATCH_SIZE_)
_LOGGING_STEPS_ = int(samples / _BATCH_SIZE_)

training_args = TrainingArguments(
    learning_rate               = _LEARNING_RATE_,
    num_train_epochs            = _EPOCHS_,
    per_device_train_batch_size = _BATCH_SIZE_,
    per_device_eval_batch_size  = 200,
    logging_steps               = _LOGGING_STEPS_,
    output_dir                  = _OUTPUT_DIR_,
    save_total_limit            = 5,
    overwrite_output_dir        = True,
    remove_unused_columns       = False,
)

# %%
from transformers import AutoAdapterModel, AutoModelForSequenceClassification
from tools.DataLoaders import DatasetCrossValnli
from transformers import AdapterTrainer
from tools.Testing import compute_author_predictions_nli, compute_author_predictions_nli_LR
from sklearn.metrics import f1_score, classification_report
import pickle


# train

task = label_name

# initialize model ---------------------------------------------------

static_head_model = AutoModelForSequenceClassification.from_pretrained(_PRETRAINED_LM_)
static_head_model.add_adapter(task, config = _ADAPTER_CONFIG_) 
static_head_model.save_adapter('aux_adapter_'+_PRED_DIR_, task)

model = AutoAdapterModel.from_pretrained(_PRETRAINED_LM_)
model.load_adapter('aux_adapter_'+_PRED_DIR_, load_as=task)
#model.load_adapter('pretrained_adapter_NLI', load_as=task)

model.set_active_adapters(task)
model.train_adapter(task)


# create trainer and train -------------------------------------------

trainer = AdapterTrainer(
    model           = model,
    args            = training_args,
    train_dataset   = Train,
)
trainer.args._n_gpu = _NO_GPUS_

trainer.train()


# get predictions ----------------------------------------------------


ignore_keys = None
if is_encoder_decoder:
    ignore_keys = ['encoder_last_hidden_state']

results            = trainer.predict(Test , ignore_keys = ignore_keys)
author_predictions = compute_author_predictions_nli(baseTest, results.predictions, task, len(class_dict), nli_label2id)

# report metrics 

report = {'soft': classification_report(author_predictions['true'], author_predictions['pred_soft'], digits=4), 
           'hard': classification_report(author_predictions['true'], author_predictions['pred_hard'], digits=4)}

print("Results:\n")
print("soft voting:\n", report['soft'], '\n')
print("hard voting:\n", report['hard'])


# get predictions with Logistic Regression----------------------------


resultsTrain = trainer.predict(Train, ignore_keys = ignore_keys)
author_predictions_LR = compute_author_predictions_nli_LR(baseTrain, baseTest, resultsTrain.predictions, results.predictions, task, len(class_dict))

# report metrics 

report_LR = {'soft': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_soft'], digits=4), 
           'hard': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_hard'], digits=4)}

print("Results using LOGISTIC REGRESSION:\n")
print("soft voting:\n", report_LR['soft'], '\n')
print("hard voting:\n", report_LR['hard'])
# Out:
# Some weights of the model checkpoint at ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli were not used when initializing BartAdapterModel: ['classification_head.dense.weight', 'classification_head.out_proj.bias', 'classification_head.dense.bias', 'classification_head.out_proj.weight']
# - This IS expected if you are initializing BartAdapterModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BartAdapterModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /001/usuarios/isaac.bribiesca/anaconda3/envs/NLP/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 144000
#   Num Epochs = 10
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 180000
#     <div>
#
#       <progress value='8036' max='180000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  8036/180000 47:30 < 16:56:44, 2.82 it/s, Epoch 0.45/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5120</td>
#       <td>0.586900</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-500
# Configuration saved in checkPointsMAMNLI/checkpoint-500/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-178000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-1000
# Configuration saved in checkPointsMAMNLI/checkpoint-1000/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-1000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-1000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-178500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-1500
# Configuration saved in checkPointsMAMNLI/checkpoint-1500/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-1500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-1500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-1500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-179000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-2000
# Configuration saved in checkPointsMAMNLI/checkpoint-2000/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-2000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-2000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-179500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-2500
# Configuration saved in checkPointsMAMNLI/checkpoint-2500/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-2500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-2500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-2500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-180000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-3000
# Configuration saved in checkPointsMAMNLI/checkpoint-3000/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-3000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-3000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-3500
# Configuration saved in checkPointsMAMNLI/checkpoint-3500/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-3500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-3500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-3500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-4000
# Configuration saved in checkPointsMAMNLI/checkpoint-4000/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-4000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-4000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-4500
# Configuration saved in checkPointsMAMNLI/checkpoint-4500/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-4500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-4500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-4500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-5000
# Configuration saved in checkPointsMAMNLI/checkpoint-5000/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-5000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-5000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-5500
# Configuration saved in checkPointsMAMNLI/checkpoint-5500/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-5500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-5500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-5500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-6000
# Configuration saved in checkPointsMAMNLI/checkpoint-6000/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-6000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-6000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-6500
# Configuration saved in checkPointsMAMNLI/checkpoint-6500/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-6500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-6500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-6500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-7000
# Configuration saved in checkPointsMAMNLI/checkpoint-7000/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-7000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-7000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-7500
# Configuration saved in checkPointsMAMNLI/checkpoint-7500/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-7500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-7500/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-7500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to checkPointsMAMNLI/checkpoint-8000
# Configuration saved in checkPointsMAMNLI/checkpoint-8000/gender/adapter_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-8000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-8000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-8000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsMAMNLI/checkpoint-8000/gender/head_config.json
# Module weights saved in checkPointsMAMNLI/checkpoint-8000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsMAMNLI/checkpoint-5500] due to args.save_total_limit

# %%
print("Results:\n")
print("soft voting:\n", report['soft'], '\n')
print("hard voting:\n", report['hard'])
# Out:
# Results:
#
# soft voting:
#                precision    recall  f1-score   support
#
#            0     0.7989    0.8675    0.8318      1200
#            1     0.8551    0.7817    0.8167      1200
#
#     accuracy                         0.8246      2400
#    macro avg     0.8270    0.8246    0.8243      2400
# weighted avg     0.8270    0.8246    0.8243      2400
#
#
# hard voting:
#                precision    recall  f1-score   support
#
#            0     0.7878    0.8908    0.8361      1200
#            1     0.8744    0.7600    0.8132      1200
#
#     accuracy                         0.8254      2400
#    macro avg     0.8311    0.8254    0.8247      2400
# weighted avg     0.8311    0.8254    0.8247      2400

# %%
print("Results using LOGISTIC REGRESSION:\n")
print("soft voting:\n", report_LR['soft'], '\n')
print("hard voting:\n", report_LR['hard'])
# Out:
# Results using LOGISTIC REGRESSION:
#
# soft voting:
#                precision    recall  f1-score   support
#
#            0     0.8068    0.8492    0.8274      1200
#            1     0.8408    0.7967    0.8181      1200
#
#     accuracy                         0.8229      2400
#    macro avg     0.8238    0.8229    0.8228      2400
# weighted avg     0.8238    0.8229    0.8228      2400
#
#
# hard voting:
#                precision    recall  f1-score   support
#
#            0     0.7946    0.8833    0.8366      1200
#            1     0.8687    0.7717    0.8173      1200
#
#     accuracy                         0.8275      2400
#    macro avg     0.8316    0.8275    0.8270      2400
# weighted avg     0.8316    0.8275    0.8270      2400

# %%
model.save_adapter('Pretrained_Adapters_NLI/'+_DATASET_+'_'+_PRED_DIR_, task)
