# %% [markdown]
# ## Set Global Seed

# %%
import os
import random
import numpy as np
import torch
import transformers

def set_all_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
seed = 260615
set_all_seeds(seed)

print("The global seed " + str(seed))
# Out:
# The global seed 260615

# %% [markdown]
# ## Hyperparameters

# %%
# LANGUAGE

_LANGUAGE_         = 'en'
_DATASET_          = '2017'

# %%
# MODEL CLASSIFICATION

_PRETRAINED_LM_    = 'ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli'
_PREPROCESS_TEXT_  = True
_TWEET_BATCH_SIZE_ = 5
_ADAPTER_CONFIG_   = transformers.HoulsbyConfig()
_MAX_SEQ_LEN_      = 150

# %%
# TRAIN

_OUTPUT_DIR_       = 'checkPointsHoulsbyNLIall'
_LOGGING_STEPS_    = 50
_NUM_AUTHORS_      = 64
_K_FOLD_CV_        = 5
_NO_GPUS_          = 1
_BATCH_SIZE_       = int(8 / _NO_GPUS_)
_EPOCHS_           = 10
_LEARNING_RATE_    = 1e-5

# PREDICTIONS

_PRED_DIR_         = 'Houlsby'

# %% [markdown]
# ## Other parameters

# %%
# LABEL DICTONARIES -----------------------------------------------------------------------

# 2015

age_dict  = {'18-24': 0, '25-34': 1, '35-49': 2, '50-XX': 3}
ageEN_hyp = {0: '18-24', 1: '25-34', 2: '35-49', 3: '50-XX'}
ageES_hyp = {0: 'La edad de esta persona es entre 18 y 24 años', 
             1: 'La edad de esta persona es entre 25 y 34 años', 
             2: 'La edad de esta persona es entre 35 y 49 años', 
             3: 'La edad de esta persona es más de 50 años'}

# 2017

gender_dict    = {'female': 0, 'male':   1}
varietyEN_dict = {'australia': 0, 'canada': 1, 'great britain': 2, 'ireland': 3, 'new zealand': 4, 'united states': 5}
varietyES_dict = {'argentina': 0, 'chile': 1, 'colombia': 2, 'mexico': 3, 'peru': 4, 'spain': 5, 'venezuela': 6}  

genderEN_hyp  = {0: 'I’m a female', 1: 'I’m a male'}
genderES_hyp  = {0: 'Mi nombre es María', 1: 'Mi nombre es José'}

# 2019

bots_dict  = {'human': 0, 'bot': 1}
botsEN_hyp = {0: 'This is a text from a person', 1: 'This is a text from a machine'}
botsES_hyp = {0: 'Humano', 1: 'Bot'}

# 2020 

fakeNews_dict  = {'0': 0, '1': 1}
fakeNewsEN_hyp = {0: 'This author is a normal user', 1: 'This author spreads fake news'}
fakeNewsES_hyp = {0: 'Este autor es un usuario normal', 1: 'Este autor publica noticias falsas'}

# 2021

hateSpeech_dict  = {'0': 0, '1': 1}
hateSpeechEN_hyp = {0: 'This text does not contain hate speech', 1: 'This text expresses prejudice and hate speech'}
hateSpeechES_hyp = {0: 'Este texto es moderado, respetuoso, cortés y civilizado', 1: 'Este texto expresa odio o prejuicios'}

# %%
# SET LANGUAGE DICTIONARIES --------------------------------------------------

if _LANGUAGE_ == 'en':
    age_hyp        = ageEN_hyp
    gender_hyp     = genderEN_hyp
    variety_dict   = varietyEN_dict
    fakeNews_hyp   = fakeNewsEN_hyp
    hateSpeech_hyp = hateSpeechEN_hyp
    bots_hyp       = botsEN_hyp 

elif _LANGUAGE_ == 'es':
    age_hyp        = ageES_hyp
    gender_hyp     = genderES_hyp
    variety_dict   = varietyES_dict
    fakeNews_hyp   = fakeNewsES_hyp
    hateSpeech_hyp = hateSpeechES_hyp
    bots_hyp       = botsES_hyp
    
    
# SET LANGUAGE AND DATASET PARAMETERS ----------------------------------------
    
if   _DATASET_ == '2015':
    label_idx  = 2
    class_dict = age_dict
    label_name = 'age'
    label_hyp  = age_hyp
    
elif _DATASET_ == '2017':
    label_idx  = 1
    class_dict = gender_dict
    label_name = 'gender'
    label_hyp  = gender_hyp
    
elif _DATASET_ == '2019':
    label_idx  = 1
    class_dict = bots_dict
    label_name = 'bots'
    label_hyp  = bots_hyp
    
elif _DATASET_ == '2020':
    label_idx  = 1
    class_dict = fakeNews_dict
    label_name = 'fakeNews'
    label_hyp  = fakeNews_hyp
    
elif _DATASET_ == '2021':
    label_idx  = 1
    class_dict = hateSpeech_dict
    label_name = 'hateSpeech'
    label_hyp  = hateSpeech_hyp

# %%
from transformers import AutoTokenizer, PretrainedConfig

tokenizer = AutoTokenizer.from_pretrained(_PRETRAINED_LM_)
vocab = tokenizer.get_vocab()

config             = PretrainedConfig.from_pretrained(_PRETRAINED_LM_)
nli_label2id       = config.label2id
is_encoder_decoder = config.is_encoder_decoder
# Out:
# You are using a model of type bart to instantiate a model of type . This is not supported for all configurations of models and can yield errors.

# %% [markdown]
# ## Datasets

# %%
# GET AUTHORS AND LABELS -----------------------------------------------------

from tools.DataLoaders import BasePAN

baseTrain  = BasePAN(Dir        = 'data/' + _DATASET_,
                     split      = 'train',
                     language   = _LANGUAGE_,
                     label_idx  = label_idx,
                     class_dict = class_dict,
                     label_name = label_name)

baseTest   = BasePAN(Dir        = 'data/' + _DATASET_,
                     split      = 'test',
                     language   = _LANGUAGE_,
                     label_idx  = label_idx,
                     class_dict = class_dict,
                     label_name = label_name)

# %%
# GET K-FOLD SPLITS -----------------------------------------------------

crossVal_splits = baseTrain.cross_val(_K_FOLD_CV_, _NUM_AUTHORS_)

crossVal_splits[0][0]
# Out:
# ['5fb799c39e1c8a92f6c580ff516bdc',
#  'c3fc612f9fe498210613a7991a1c7f2a',
#  '7a2b6e351032615aa3c19d8c252bd552',
#  '5849edbc23ee81353911f951e0903ea',
#  '42dc691f860354271b77171b152967cf',
#  '7ffdaa0d7d70f8c485e3f645aa9ba7d9',
#  '49a6b94266d28dd3e241905d2300e504',
#  'ad6faf0d1624a7015f0eab10a6516fc2',
#  'c93fd1e3c9e5ba437a544db7b84e375e',
#  '5fc0d0a6f90891a3cb4b32d7169e6676',
#  '60705218ce29389bb7181837d701556e',
#  '56b4ff0baba162a5c53323fe3dcd0d64',
#  'a9430efa05e5abc56310ff9a5173cd07',
#  '87318fe9b132b934dd298c3f7f3fbcf6',
#  'd052413e23540da3e613f466e53a1317',
#  '1342f1fee84567cda4741b41a770b4e0',
#  '1de5e53b813163d9c5105cd15ccaa842',
#  '4dbd49cb6fe542993bfd0b968be669bd',
#  'e9cd1a184a4c34f480748df1bd3d2bf6',
#  '505da57fd58bb00c6a164789c9658c58',
#  'b123667f9d6697eb2828dc00920099fc',
#  'b89bdf194952b1e65de3ba5d8cf35305',
#  '47a9df75b78c187edebc2a740b118dc8',
#  'ad1b99bd41ef75f70cd2e8406e254015',
#  '31e8a4b69e210ed705c0901d41818ad',
#  'f860e1654982c95af3c7da43c3d0ef94',
#  '7fd945221f3a712a1223810e2b1ddc10',
#  'b2e5086a0e2f263f48ba1bec23dcc32',
#  '588c6b6f2976e618bfba46ced2cbd541',
#  '6e1911c6d55057ac78a23c2a6aced69a',
#  '1575fbaefda30e5b4eb3f3575ec0c16',
#  'e24bfcc7901e5342625bbdc73aac6e',
#  '5cdc7610ce9a2f6473c5f96a790ec370',
#  'ff70773bfc4388c4d233a9cbcb7bd240',
#  'fce86ef8121f54da04737c03bcd64301',
#  'b9a594f31b4c964a2a6b8ed902d48e9e',
#  '4f2c42e7f7266b0a18bfe513d70191',
#  'cf66a7f2ca1f5a40dbce1868cf1d8cc0',
#  '11af0d26a672c7da826161a7f3abd0f1',
#  'e6d8e40bf4b68042ce3872829d30efab',
#  '669479df8376ab58c2e43857dc6c93fa',
#  'ad30ac48952941c086864a12aa5bfc62',
#  '9c1a9017126ac337eb43fdc644a80bc3',
#  '609885913e5cbb1b3092c773f0c922a5',
#  'b19565eaa051b46ba80ad77759244fe4',
#  '49b656b5a03b13912234412825651da6',
#  'bca91125c4d09175a44d90777dbf392',
#  '9d45dc101bd9ca0014166756dca679f2',
#  '9ec6cd1ae201fb59df9b2e8902a1d185',
#  '95d8b6e47d58d6f05f060f6f91e404ef',
#  '305be2de52acb7595fbc7c6284f202f2',
#  '337493831ca980b59bb5047f96228032',
#  'e03d5e6b7f64f0dd50877ad632dcbd53',
#  'a1d180378e217a05fe06a083243491bb',
#  'c2a05de2cc5d7b19e83f198bf684dcd8',
#  'ecfa46a8e0aacc862332d4edc8065b43',
#  'e4904f5d9f0aef32c15d9244642aa776',
#  'f36809bbb9523c493ab52311c1998db',
#  '3d271756269ef7ab523eea2148121a1c',
#  '5303fe3cc0c49231c5f37bb41d5430c1',
#  'dc98b0f37c05812764a25d4250451fa3',
#  '80376c3e6155234e4e1eb8a4f2fc1dc8',
#  'df959a898742c0e89367965d56101b2d',
#  'cf153a881d0bd746224fa16c5fc49262',
#  'bbf89d3082bad3070da8126eb9ed27ff',
#  '2327e9f918d9800d27db78f6c7e229c6',
#  'e08bdc4a6991bda3fdfb72703fb7f638',
#  'e09f601f00315551ab943444d0c57726',
#  '8de2d798f39945d58d4a8a51ce00077b',
#  'bdc7dea6b2cc49bfedc4e28540bfe06c',
#  'b711e060295084c346bfec2b53677d69',
#  'd857f3e6b85bec0e58893b3c2c401cfe',
#  '898806f9b2d2ecd4b95d5997d61e4c6c',
#  '3aca68dfccecc70810dcfe0edae6d64c',
#  'ac0ad5ef82c0feaa72dbfeb4eb8ae9ea',
#  '83a6a5649de4cec10b5dfa9520c661d3',
#  'bdaf69b1892ebe83996d23a7df39ab23',
#  '9a50e74b9f805526aaaf08631bb2af77',
#  '84a4c311516931f8db18954564e91682',
#  '60b727e25925cfb9d4c2777dc21be91e',
#  '4d8ddb27a2cf60abeb1dc017dff70a08',
#  '33dfeb2341ffde08d675b34e03fcfc71',
#  'b6b72fb81cb82ddff134d566a0c64cb8',
#  'dcc8aba9bfec3cfa9badd1d1856722f0',
#  '4acbad7d312a507cc868d1ee7850b1df',
#  'd9a3d7414732809ae706d5408860a8b5',
#  'f6542bf23890b58b002bece1bc873a4',
#  'fbdfb0523ce14f4ae454383b57ddb418',
#  'eb76ed8d8ef9459701e3b0153edb0109',
#  '9d2ea2a212bfaccfe7605163b34ee00c',
#  '569dfb32d282e89d3602f3cd8d49a34a',
#  '6b11fb9c4592c35f4422c9b3f749aaf8',
#  '286bc560e5b574b904075717ffa46932',
#  '48185885073828455f28e3bac6fce016',
#  '70355ce4b88f91a3b920a37e5f0051c5',
#  '5e66c80df9542d3b3250858b1f9e4d0e',
#  'b3b89ac594b609dda2c64ed61499714f',
#  'ba6f1a42a9f0e593eb9a9ed239bae00',
#  '356da3bba0e1527fb5781865c45ad272',
#  '7b8e315e12b46c2f3eed44059b04b09d',
#  'c614cb857beb568780f707da37042aa0',
#  '1696ecf15f18b4f5af1c1caa13803b49',
#  '438c210946d60a1f2c31d62b1d6fa721',
#  'dbeb0315430511c9ae8e41c323a26534',
#  'b64c7144274829ac128541069031181',
#  '6f965389f1ab87d9434c0be2b42aadba',
#  '8cac09b7810d44fc46815f1c232c732a',
#  '46d44c9d672a0f618e95750d2c3174e8',
#  '686d0f57cb3cd9c89bd9d4ff5a3767ba',
#  '66eabf9f244ccf162fda0500d9d6891a',
#  '79fa379118aea2f9983dab1a707afaca',
#  'd9e4b20963a5605d9f12b158e61ba06f',
#  '84545f5df44427a69ec5450b7f56c512',
#  '2c1729860df3f892b101b96bbf6c530c',
#  'd93f1b9191b509b9cfaed1115922d08d',
#  '80137c5de896f6ad4ccbc7e0151d6ca8',
#  'f018af7405a2be33c56a2d9d9c056c59',
#  'fc2d964e60718790690e9448db99e9e7',
#  'db8efea34d6391b8596812cca2973cb0',
#  'af2dc83343e637dfab2d3d3715025888',
#  'b59719c7abe16b6c552085579fd2f22f',
#  '73955ade234750cdd6974a14b25c64eb',
#  'b978cbbd6d0dac95acc5147f21461bad',
#  '505b37078d17e53dc12b206c6115163c',
#  '835a707182f1dba8a0672fcb03f7c8a9',
#  'b2090a6b6f2ad25d058d081825403b85',
#  'fe13ae20c24d8dab364bcb5928e83259',
#  '9abb3906165444e9d9d5c504f7432714']

# %%
# GET TWEETS -----------------------------------------------------

baseTrain.get_all_data(_TWEET_BATCH_SIZE_, tokenizer, _MAX_SEQ_LEN_, _PREPROCESS_TEXT_, NLI=True, label_hyp=label_hyp, nli_label2id=nli_label2id)
# Out:
# Reading data...
#     Done
# Preprocessing text...
#     Done
# Tokenizing...
#     Done
# Merging data...
#     Done
#
# Total Instances: 144000

# %% [markdown]
# ## Training with all

# %%
from tools.DataLoaders import DatasetPANnli

baseTest.get_all_data(_TWEET_BATCH_SIZE_, tokenizer, _MAX_SEQ_LEN_, _PREPROCESS_TEXT_, NLI=True, label_hyp=label_hyp, nli_label2id=nli_label2id)

Test  = DatasetPANnli(baseTest)
Train = DatasetPANnli(baseTrain)
# Out:
# Reading data...
#     Done
# Preprocessing text...
#     Done
# Tokenizing...
#     Done
# Merging data...
#     Done
#
# Total Instances: 96000

# %%
from transformers import TrainingArguments

samples = 4 * _NUM_AUTHORS_ * int(100 / _TWEET_BATCH_SIZE_)
_LOGGING_STEPS_ = int(samples / _BATCH_SIZE_)

training_args = TrainingArguments(
    learning_rate               = _LEARNING_RATE_,
    num_train_epochs            = _EPOCHS_,
    per_device_train_batch_size = _BATCH_SIZE_,
    per_device_eval_batch_size  = 200,
    logging_steps               = _LOGGING_STEPS_,
    output_dir                  = _OUTPUT_DIR_,
    save_total_limit            = 5,
    overwrite_output_dir        = True,
    remove_unused_columns       = False,
)

# %%
from transformers import AutoAdapterModel, AutoModelForSequenceClassification
from tools.DataLoaders import DatasetCrossValnli
from transformers import AdapterTrainer
from tools.Testing import compute_author_predictions_nli, compute_author_predictions_nli_LR
from sklearn.metrics import f1_score, classification_report
import pickle


# train

task = label_name

# initialize model ---------------------------------------------------


#static_head_model = AutoModelForSequenceClassification.from_pretrained(_PRETRAINED_LM_)
#static_head_model.add_adapter(task, config = _ADAPTER_CONFIG_) 
#static_head_model.save_adapter('aux_adapter', task)

model = AutoAdapterModel.from_pretrained(_PRETRAINED_LM_)
#model.load_adapter('aux_adapter', load_as=task)
model.load_adapter('pretrained_adapter_NLI', load_as=task)

model.set_active_adapters(task)
model.train_adapter(task)


# create trainer and train -------------------------------------------

trainer = AdapterTrainer(
    model           = model,
    args            = training_args,
    train_dataset   = Train,
)
trainer.args._n_gpu = _NO_GPUS_

trainer.train()


# get predictions ----------------------------------------------------


ignore_keys = None
if is_encoder_decoder:
    ignore_keys = ['encoder_last_hidden_state']

results            = trainer.predict(Test , ignore_keys = ignore_keys)
author_predictions = compute_author_predictions_nli(baseTest, results.predictions, task, len(class_dict), nli_label2id)

# report metrics 

report = {'soft': classification_report(author_predictions['true'], author_predictions['pred_soft'], digits=4), 
           'hard': classification_report(author_predictions['true'], author_predictions['pred_hard'], digits=4)}

print("Results:\n")
print("soft voting:\n", report['soft'], '\n')
print("hard voting:\n", report['hard'])


# get predictions with Logistic Regression----------------------------


resultsTrain = trainer.predict(Train, ignore_keys = ignore_keys)
author_predictions_LR = compute_author_predictions_nli_LR(baseTrain, baseTest, resultsTrain.predictions, results.predictions, task, len(class_dict))

# report metrics 

report_LR = {'soft': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_soft'], digits=4), 
           'hard': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_hard'], digits=4)}

print("Results using LOGISTIC REGRESSION:\n")
print("soft voting:\n", report_LR['soft'], '\n')
print("hard voting:\n", report_LR['hard'])
# Out:
# Some weights of the model checkpoint at ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli were not used when initializing BartAdapterModel: ['classification_head.dense.weight', 'classification_head.dense.bias', 'classification_head.out_proj.bias', 'classification_head.out_proj.weight']
# - This IS expected if you are initializing BartAdapterModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BartAdapterModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /001/usuarios/isaac.bribiesca/anaconda3/envs/NLP/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 144000
#   Num Epochs = 10
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 180000
#     <div>
#
#       <progress value='14870' max='180000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 14870/180000 1:17:32 < 14:21:09, 3.20 it/s, Epoch 0.83/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>640</td>
#       <td>0.511400</td>
#     </tr>
#     <tr>
#       <td>1280</td>
#       <td>0.511300</td>
#     </tr>
#     <tr>
#       <td>1920</td>
#       <td>0.517600</td>
#     </tr>
#     <tr>
#       <td>2560</td>
#       <td>0.511800</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.518100</td>
#     </tr>
#     <tr>
#       <td>3840</td>
#       <td>0.513700</td>
#     </tr>
#     <tr>
#       <td>4480</td>
#       <td>0.506000</td>
#     </tr>
#     <tr>
#       <td>5120</td>
#       <td>0.501700</td>
#     </tr>
#     <tr>
#       <td>5760</td>
#       <td>0.515600</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.509500</td>
#     </tr>
#     <tr>
#       <td>7040</td>
#       <td>0.502900</td>
#     </tr>
#     <tr>
#       <td>7680</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>8320</td>
#       <td>0.509400</td>
#     </tr>
#     <tr>
#       <td>8960</td>
#       <td>0.488100</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>0.506600</td>
#     </tr>
#     <tr>
#       <td>10240</td>
#       <td>0.489800</td>
#     </tr>
#     <tr>
#       <td>10880</td>
#       <td>0.506700</td>
#     </tr>
#     <tr>
#       <td>11520</td>
#       <td>0.491400</td>
#     </tr>
#     <tr>
#       <td>12160</td>
#       <td>0.510500</td>
#     </tr>
#     <tr>
#       <td>12800</td>
#       <td>0.505100</td>
#     </tr>
#     <tr>
#       <td>13440</td>
#       <td>0.506100</td>
#     </tr>
#     <tr>
#       <td>14080</td>
#       <td>0.522300</td>
#     </tr>
#     <tr>
#       <td>14720</td>
#       <td>0.512000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-500/gender/pytorch_model_head.bin
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-1000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-1000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-1000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-1000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-1000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-1000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-1000/gender/pytorch_model_head.bin
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-1500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-1500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-1500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-1500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-1500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-1500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-1500/gender/pytorch_model_head.bin
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-2000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-2000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-2000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-2000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-2000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-2000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-2000/gender/pytorch_model_head.bin
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-2500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-2500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-2500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-2500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-2500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-2500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-2500/gender/pytorch_model_head.bin
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-3000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-3000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-3000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-3000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-3000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-3000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-3000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-3500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-3500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-3500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-3500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-3500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-3500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-3500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-4000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-4000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-4000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-4000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-4000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-4000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-4000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-4500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-4500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-4500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-4500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-4500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-4500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-4500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-5000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-5000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-5000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-5000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-5000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-5000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-5000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-5500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-5500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-5500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-5500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-5500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-5500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-5500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-6000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-6000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-6000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-6000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-6000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-6000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-6000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-6500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-6500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-6500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-6500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-6500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-6500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-6500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-7000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-7000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-7000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-7000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-7000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-7000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-7000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-7500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-7500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-7500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-7500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-7500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-7500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-7500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-8000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-8000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-8000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-8000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-8000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-8000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-8000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-5500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-8500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-8500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-8500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-8500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-8500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-8500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-8500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-9000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-9000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-9000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-9000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-9000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-9000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-9000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-9500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-9500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-9500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-9500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-9500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-9500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-9500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-10000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-10000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-10000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-10000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-10000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-10000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-10000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-10500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-10500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-10500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-10500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-10500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-10500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-10500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-11000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-11000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-11000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-11000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-11000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-11000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-11000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-8500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-11500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-11500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-11500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-11500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-11500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-11500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-11500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-12000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-12000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-12000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-12000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-12000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-12000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-12000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-9500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-12500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-12500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-12500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-12500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-12500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-12500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-12500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-10000] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-13000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-13000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-13000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-13000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-13000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-13000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-13000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-10500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-13500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-13500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-13500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-13500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-13500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-13500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-13500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-11000] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-14000
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-14000/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-14000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-14000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-14000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-14000/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-14000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-11500] due to args.save_total_limit
# Saving model checkpoint to checkPointsHoulsbyNLIall/checkpoint-14500
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-14500/gender/adapter_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-14500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-14500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-14500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsHoulsbyNLIall/checkpoint-14500/gender/head_config.json
# Module weights saved in checkPointsHoulsbyNLIall/checkpoint-14500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsHoulsbyNLIall/checkpoint-12000] due to args.save_total_limit

# %%
print("Results:\n")
print("soft voting:\n", report['soft'], '\n')
print("hard voting:\n", report['hard'])
# Out:
# Results:
#
# soft voting:
#                precision    recall  f1-score   support
#
#            0     0.7814    0.8908    0.8326      1200
#            1     0.8731    0.7508    0.8073      1200
#
#     accuracy                         0.8208      2400
#    macro avg     0.8272    0.8208    0.8200      2400
# weighted avg     0.8272    0.8208    0.8200      2400
#
#
# hard voting:
#                precision    recall  f1-score   support
#
#            0     0.7691    0.8992    0.8290      1200
#            1     0.8786    0.7300    0.7975      1200
#
#     accuracy                         0.8146      2400
#    macro avg     0.8239    0.8146    0.8132      2400
# weighted avg     0.8239    0.8146    0.8132      2400

# %%
print("Results using LOGISTIC REGRESSION:\n")
print("soft voting:\n", report_LR['soft'], '\n')
print("hard voting:\n", report_LR['hard'])
# Out:
# Results using LOGISTIC REGRESSION:
#
# soft voting:
#                precision    recall  f1-score   support
#
#            0     0.8076    0.8500    0.8283      1200
#            1     0.8417    0.7975    0.8190      1200
#
#     accuracy                         0.8237      2400
#    macro avg     0.8246    0.8237    0.8236      2400
# weighted avg     0.8246    0.8237    0.8236      2400
#
#
# hard voting:
#                precision    recall  f1-score   support
#
#            0     0.7943    0.8592    0.8255      1200
#            1     0.8466    0.7775    0.8106      1200
#
#     accuracy                         0.8183      2400
#    macro avg     0.8205    0.8183    0.8180      2400
# weighted avg     0.8205    0.8183    0.8180      2400

# %%
model.save_adapter('Pretrained_Adapters_NLI/'+_DATASET_+'_'+_PRED_DIR_, task)
