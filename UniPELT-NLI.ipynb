# %% [markdown]
# ## Set Global Seed

# %%
import os
import random
import numpy as np
import torch
import transformers

def set_all_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
seed = 260615
set_all_seeds(seed)

print("The global seed " + str(seed))
# Out:
# The global seed 260615

# %% [markdown]
# ## Hyperparameters

# %%
# LANGUAGE

_LANGUAGE_         = 'en'
_DATASET_          = '2021'

# %%
# MODEL CLASSIFICATION

_PRETRAINED_LM_    = 'ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli'
_PREPROCESS_TEXT_  = True
_TWEET_BATCH_SIZE_ = 5
_ADAPTER_CONFIG_   = transformers.UniPELTConfig()
_MAX_SEQ_LEN_      = 150

# %%
# TRAIN

_OUTPUT_DIR_       = 'checkPointsUniPELTNLI'
_LOGGING_STEPS_    = 50
_NUM_AUTHORS_      = 512
_K_FOLD_CV_        = 5
_NO_GPUS_          = 1
_BATCH_SIZE_       = int(8 / _NO_GPUS_)
_EPOCHS_           = 10
_LEARNING_RATE_    = 1e-5

# PREDICTIONS

_PRED_DIR_         = 'pretrainedUniPELTNLI'
_PRETRAINED_ADAPTER_ = '2017_UniPELTNLI'

# %% [markdown]
# ## Other parameters

# %%
# LABEL DICTONARIES -----------------------------------------------------------------------

# 2015

age_dict  = {'18-24': 0, '25-34': 1, '35-49': 2, '50-XX': 3}
ageEN_hyp = {0: '18-24', 1: '25-34', 2: '35-49', 3: '50-XX'}
ageES_hyp = {0: 'La edad de esta persona es entre 18 y 24 años', 
             1: 'La edad de esta persona es entre 25 y 34 años', 
             2: 'La edad de esta persona es entre 35 y 49 años', 
             3: 'La edad de esta persona es más de 50 años'}

# 2017

gender_dict    = {'female': 0, 'male':   1}
varietyEN_dict = {'australia': 0, 'canada': 1, 'great britain': 2, 'ireland': 3, 'new zealand': 4, 'united states': 5}
varietyES_dict = {'argentina': 0, 'chile': 1, 'colombia': 2, 'mexico': 3, 'peru': 4, 'spain': 5, 'venezuela': 6}  

genderEN_hyp  = {0: 'I’m a female', 1: 'I’m a male'}
genderES_hyp  = {0: 'Mi nombre es María', 1: 'Mi nombre es José'}

# 2019

bots_dict  = {'human': 0, 'bot': 1}
botsEN_hyp = {0: 'This is a text from a person', 1: 'This is a text from a machine'}
botsES_hyp = {0: 'Humano', 1: 'Bot'}

# 2020 

fakeNews_dict  = {'0': 0, '1': 1}
fakeNewsEN_hyp = {0: 'This author is a normal user', 1: 'This author spreads fake news'}
fakeNewsES_hyp = {0: 'Este autor es un usuario normal', 1: 'Este autor publica noticias falsas'}

# 2021

hateSpeech_dict  = {'0': 0, '1': 1}
hateSpeechEN_hyp = {0: 'This text does not contain hate speech', 1: 'This text expresses prejudice and hate speech'}
hateSpeechES_hyp = {0: 'Este texto es moderado, respetuoso, cortés y civilizado', 1: 'Este texto expresa odio o prejuicios'}

# %%
# SET LANGUAGE DICTIONARIES --------------------------------------------------

if _LANGUAGE_ == 'en':
    age_hyp        = ageEN_hyp
    gender_hyp     = genderEN_hyp
    variety_dict   = varietyEN_dict
    fakeNews_hyp   = fakeNewsEN_hyp
    hateSpeech_hyp = hateSpeechEN_hyp
    bots_hyp       = botsEN_hyp 

elif _LANGUAGE_ == 'es':
    age_hyp        = ageES_hyp
    gender_hyp     = genderES_hyp
    variety_dict   = varietyES_dict
    fakeNews_hyp   = fakeNewsES_hyp
    hateSpeech_hyp = hateSpeechES_hyp
    bots_hyp       = botsES_hyp
    
    
# SET LANGUAGE AND DATASET PARAMETERS ----------------------------------------
    
if   _DATASET_ == '2015':
    label_idx  = 2
    class_dict = age_dict
    label_name = 'age'
    label_hyp  = age_hyp
    
elif _DATASET_ == '2017':
    label_idx  = 1
    class_dict = gender_dict
    label_name = 'gender'
    label_hyp  = gender_hyp
    
elif _DATASET_ == '2019':
    label_idx  = 1
    class_dict = bots_dict
    label_name = 'bots'
    label_hyp  = bots_hyp
    
elif _DATASET_ == '2020':
    label_idx  = 1
    class_dict = fakeNews_dict
    label_name = 'fakeNews'
    label_hyp  = fakeNews_hyp
    
elif _DATASET_ == '2021':
    label_idx  = 1
    class_dict = hateSpeech_dict
    label_name = 'hateSpeech'
    label_hyp  = hateSpeech_hyp

# %%
from transformers import AutoTokenizer, PretrainedConfig

tokenizer = AutoTokenizer.from_pretrained(_PRETRAINED_LM_)
vocab = tokenizer.get_vocab()

config             = PretrainedConfig.from_pretrained(_PRETRAINED_LM_)
nli_label2id       = config.label2id
is_encoder_decoder = config.is_encoder_decoder
# Out:
# You are using a model of type bart to instantiate a model of type . This is not supported for all configurations of models and can yield errors.

# %% [markdown]
# ## Datasets

# %%
# GET AUTHORS AND LABELS -----------------------------------------------------

from tools.DataLoaders import BasePAN

baseTrain  = BasePAN(Dir        = 'data/' + _DATASET_,
                     split      = 'train',
                     language   = _LANGUAGE_,
                     label_idx  = label_idx,
                     class_dict = class_dict,
                     label_name = label_name)

baseTest   = BasePAN(Dir        = 'data/' + _DATASET_,
                     split      = 'test',
                     language   = _LANGUAGE_,
                     label_idx  = label_idx,
                     class_dict = class_dict,
                     label_name = label_name)

# %%
# GET K-FOLD SPLITS -----------------------------------------------------

crossVal_splits = baseTrain.cross_val(_K_FOLD_CV_, _NUM_AUTHORS_)

crossVal_splits[0][0]
# Out:
# ['f2b1fc84c500c38a93522efbd422b559',
#  'e46a97a03fd592113aa233d1637ed0fd',
#  'fdef657f264ca50bc7b21574b24f82ab',
#  '4d4c5dcbfe38d0d33a0d1b1419952ca8',
#  '7f269488a6576c9dc21085c1e2854142',
#  '3b2d9429387f770b388edbefd881fc38',
#  '4ae4ddc8cb2774c92398e3102c3da5b2',
#  '47af667ddc145dd68323c9bef1408e0d',
#  '365eb1e3abc5cd5394fec8fc162bfbc5',
#  'fdb47a3f65091b9a5b989e1722c9fac4',
#  'b4030e7f9f049a602defab723599fdeb',
#  '2a9776a2909ba5e27043faf2d57ba410',
#  '3770a07b212c1096c26e5a1f1556fbd1',
#  '6fd5e2e31d6c2b2eb4b5dc07280636a7',
#  '9d58d6313bfb2fba9e1e45bb9d65cf0b',
#  '135cc1b889864768b5c755eb6210d358',
#  '6fe4ed1ee7f13da10a62d3cd1a6cba07',
#  '95ccf1511784da6b392971bc1efbca19',
#  'b496caf332cb0ba97d2acefc44f153ac',
#  'e5f932198bf18fe7a51d131fceb81707',
#  '4f496db1408c402eb21d29e536667205',
#  '4643c543b666aedb6157ae37e92ccc75',
#  'da28bc4cb0849abd43cc116509b3485c',
#  'a8e2397021acef98cc32729cbda96910',
#  'd2e0f4f0244b9b8b3bbd8b1654be5b74',
#  '91aef160991f1aec1b61550d6cd71abb',
#  '06893abba0bb8f94fed7562350233ed7',
#  'a887ec85088a87e550015e2770a6e309',
#  '4253c341c1069eded30b6efd2df89ddc',
#  '41eff6afb1ced61ab38e4d86d56825e0',
#  '9cff4936f8479d53fcbb63f2524c5ad8',
#  'f3eecd0eedab3b77558d93b1b92579a4',
#  '0e86e9b6ba971cbc5a117c4af6fad9a2',
#  'ed940505af044f823b90d44d5ebad88e',
#  'efd470e6959c076c9c0456b33509e8bd',
#  'e8b833650d2e91d234d621f4dd0c1031',
#  'bd0d6b9c924fdc0eb8274bbe7b7a6e2c',
#  '9d08913250938aadcf6c18d0c89a0d14',
#  'e6e216a24993a72629629da7c182c3af',
#  '748c4b31797d62bcce99de35a681b484',
#  '562b522eacbcf4484566f658aed140aa',
#  '30be488aa93e8000aadb952a9cd5143c',
#  '1a91d52030d1a433d35055fbeb6bdf3b',
#  '3df768933d03108ea4c6583d49c85c46',
#  '54f81e27af90ed7c1c9409c332f0ca37',
#  '45bb70e3f298f2c62d683e3971481552',
#  '1df25475b1cb684b7937bd49afb79fc0',
#  '639b8e5e6a527d494c85d8f5704b1a01',
#  'd15ec49115f2e8febee7fda9d1893fa4',
#  '86a7f84c2dd126dac46270b6c912952c',
#  '4a1baf66990e0e540effd01f4b105f44',
#  '5625ca3bc44c89d763221b663f7c0987',
#  '8b525999b04b19255b32365e49b281ac',
#  '4cbee4f8451fb69d309b7a6ccf7709f9',
#  'f207e0510b20e6cb0e4485a9f9be7eb9',
#  '58584745632b5367da1c7a9af746222b',
#  'b8924a54bb6043c56969e20a328b76b3',
#  '43641af5b9182e88190638f972eb97eb',
#  '10b2d013382e1fb3c9414ea28329f258',
#  '76e152a7732922e7a6da39880486107f',
#  '34e9918b10fe1fdd757855b62abc0efc',
#  'b5c35f78bd8c275b97532cd63ccd6ad8',
#  '6711ef348ffcb3e45d2957396a4c8026',
#  '94b5cb02328011bbecaf78d79d2c1ff5',
#  '3de62c6202ee8e06c74c3a6d4833e068',
#  'feab35da86bf5f84085fb670cb2866e4',
#  '98b4a082eba0660ee1360aac24f162ef',
#  '4ab73bdea1111e16bf6ef8b34e3f121b',
#  '450d7d3b3873914d5ebf3fe4782d20bd',
#  '99cb2cd23f7cf613d394502d17dedad0',
#  'd9a3d6cfc4e58f3ea9e9e5959d0d0324',
#  'aa917a8c5a4420b024274672667c7dc1',
#  'f11ca441819610286438d812af4e5e52',
#  'aa14b4634d37596c9ed9827f077194b9',
#  '98c59ff3e2cfc56b96ee3c49b3d46296',
#  'b5fc924814e26ca9e4f64c42c3f6dd90',
#  '26644d1348fc1122e8c5ef45d6bc84fa',
#  '258ba7b57bc38e4987f9f3cf23700ece',
#  '6d3988b400f07e05521f71b0ee8111e6',
#  '1005765475f523b3436d795b2e229174',
#  '1b10072ed58f20f27d8fe35580ad26d4',
#  '6b6eb2370271fbf26dcc73195218edcb',
#  'f63c22363b3db5f3d76db1f2417adb39',
#  '69dd2e9ef1897355337376a7d574e882',
#  'b264ae3f49a660c4dbd63d654175471b',
#  'ca1c941118dcde7855423d0101a637c6',
#  'e5cc453c1de4371b8d668c3ab50126f1',
#  'b7f4ead8c975203082dcea622621d2c3',
#  'b67d6746fefbe67981ca8454faa82988',
#  '2e1bdf04f415dd3bf3ffcd950ad1c541',
#  '8b7608a503048538181399629fe67913',
#  '5d4a0908d433733c14c38261fc4f4250',
#  '63a133c55e234d7ccb1f4ce9ded79f91',
#  'afe04507770754d25fcdaa901841d440',
#  'f6ccc99dd7a54cb2d692f4aa3049efc1',
#  '16252bfc43f2facd313ce084d412b592',
#  'f3124b62d50000cafbee9ce81f7c9e6d',
#  '833ffc26e9f1a81265e3e97513cefb86',
#  'a7d4e6f2aa8543a448b5a07feab9fc49',
#  'cc42228c1ba6c289b56acb78eccb0e7e',
#  'c50505ec1514ce8b7ed8e9bc92eb43b1',
#  'd28b60028cf7bcf8a9f145193e261ecf',
#  '9e3b14eef764e6c0a2cd488a5ab2e2be',
#  'd2a222ef792ca0667f2af63dcd1baf34',
#  '4bde12da41b2ded3de456ce8f334039c',
#  'c343cb70d741dc3ee88d26d0fc04be60',
#  '342a27905d2291b55486c257d77265b4',
#  'f8bce0042a6c8fcfdb585a052e998afb',
#  'e9f06b27f1108050bd27937cbacb1d5e',
#  '6ea97aacfeaa4684acc0fcbc30e998d6',
#  'f6b4231dfadff637ebee124079bdce3e',
#  'd47a4b83cd692b1c0c5e8444bf1bc2a5',
#  '241be75a5da1d1c6533cfde9657e829c',
#  'e608b622e6a3085290fc279b55fa821c',
#  '83509a9da9ef01b1255d826abd587a93',
#  '0f1974d237ad2265fa0eb09193fa42f4',
#  'cc40716d2f9ca1b14b8ac542a5ac8eef',
#  '0d02a3f644c9313315ecc6655ccfa3b9',
#  '44e25d1ec3f786a696e0eb5b33b8325b',
#  'f00627537c48b43bf2045b98b3508d94',
#  'dead14502e55f545546f666ab6d91558',
#  '5e47f30caa62ab081b1a2dcb8d3caf30',
#  '56498bda31b85f3ed955dfb8ab47a909',
#  'db83cb088416759db148c17b256a9652',
#  'e886cf9468db977abd24c7a068234609',
#  'e30b87c8fa34a1ac077d7b286000bc06',
#  '77822fc7312f39c95643c383702d9546',
#  'e1f66f003824f12344cf1ace242adf0e',
#  'c129b2cf075e1872a86ce8f7473819af',
#  '41501686277ace6b5fd7dcfe9284fe1d',
#  '74234d3105c22f51e4ad3d133f5eb8ba',
#  '89866dca3febf2d6b97c796250528a8d',
#  'aba7a9ab2d9d07953cabcaf6793be635',
#  '0a6700c6023c6249bcc5820e2f5ee0de',
#  'f902c0eaa0ff3818f6c22ebfae52ab43',
#  '2f3e55e23c53a4572fe496d34109070a',
#  'b34dcc081342bfadb3a82039d4e4eede',
#  'a37a032f4a0c42bc3ba3663db6907bfb',
#  'e07fa74c2ce94aaf2bc43b0b313d02da',
#  '0a3ce42bea89e2a92a28f685735e605e',
#  '501a0adf8d2f2a8454d6273179d035c1',
#  '65042b6a94addf20c6fafd782c5d4347',
#  'fdb9f16899e3097e6db1f6a13d3572f8',
#  'a63fc743cd9e06a05bb6cc6fb2a577fa',
#  '78537787441ed0d11da43122f9b0520a',
#  '5b5c08b665052e695064f2f2b04bdea7',
#  '5c8c5dde745f6b4d478f6fb619b24b95',
#  'f91fa8ecdd2440eb163516769573f24a',
#  'cb7b2b7612c3d7ca299387a47393f7e9',
#  '1cb7af9f85f4cb41b33d105334173862',
#  'bbd46b0659de5a173339aaebac2523fa',
#  'e8a408c9e9859d68a499324449b80c65',
#  '62a6b5a0c5f53790c114639c7ec0a3ab',
#  'f8c996ef2325dddab520230237fdfa80',
#  'cecc9d84dbc069af5579b55577d0e83e',
#  'bb824be390d6e87696fb803bbee77833',
#  'c8006e782052410e43cdcdda668d11c4',
#  'b9a46d0b178f190985de7145d5854810',
#  '98e4c6520892b0218ab13ca7369785be',
#  'ad7eaa2c1d5daa1aa71719be4357c428']

# %%
# GET TWEETS -----------------------------------------------------

baseTrain.get_all_data(_TWEET_BATCH_SIZE_, tokenizer, _MAX_SEQ_LEN_, _PREPROCESS_TEXT_, NLI=True, label_hyp=label_hyp, nli_label2id=nli_label2id)
# Out:
# Reading data...
#     Done
# Preprocessing text...
#     Done
# Tokenizing...
#     Done
# Merging data...
#     Done
#
# Total Instances: 16000

# %% [markdown]
# ## Training and Testing

# %%
from tools.DataLoaders import DatasetPANnli

baseTest.get_all_data(_TWEET_BATCH_SIZE_, tokenizer, _MAX_SEQ_LEN_, _PREPROCESS_TEXT_, NLI=True, label_hyp=label_hyp, nli_label2id=nli_label2id)

Test = DatasetPANnli(baseTest)
# Out:
# Reading data...
#     Done
# Preprocessing text...
#     Done
# Tokenizing...
#     Done
# Merging data...
#     Done
#
# Total Instances: 8000

# %%
from transformers import TrainingArguments

samples = 4 * _NUM_AUTHORS_ * int(100 / _TWEET_BATCH_SIZE_)
_LOGGING_STEPS_ = int(samples / _BATCH_SIZE_)

training_args = TrainingArguments(
    learning_rate               = _LEARNING_RATE_,
    num_train_epochs            = _EPOCHS_,
    per_device_train_batch_size = _BATCH_SIZE_,
    per_device_eval_batch_size  = 200,
    logging_steps               = _LOGGING_STEPS_,
    output_dir                  = _OUTPUT_DIR_,
    save_total_limit            = 5,
    overwrite_output_dir        = True,
    remove_unused_columns       = False,
)

# %%
from transformers import AutoAdapterModel, AutoModelForSequenceClassification
from tools.DataLoaders import DatasetCrossValnli
from transformers import AdapterTrainer
from tools.Testing import compute_author_predictions_nli, compute_author_predictions_nli_LR
from sklearn.metrics import f1_score, classification_report
import pickle


# train

task = label_name

f1s_soft = []
f1s_hard = []

f1s_soft_LR = []
f1s_hard_LR = []

for split in range( _K_FOLD_CV_ ):
    
    # loaders for current split ------------------------------------------
    
    authors_train, authors_val = crossVal_splits[split]
    
    Train = DatasetCrossValnli(baseTrain, authors_train)
    Val   = DatasetCrossValnli(baseTrain, authors_val)
    
    
    # initialize model ---------------------------------------------------
    

    #static_head_model = AutoModelForSequenceClassification.from_pretrained(_PRETRAINED_LM_)
    #static_head_model.add_adapter(task, config = _ADAPTER_CONFIG_) 
    #static_head_model.save_adapter('aux_adapter_'+_PRED_DIR_, task)

    model = AutoAdapterModel.from_pretrained(_PRETRAINED_LM_)
    #model.load_adapter('aux_adapter_'+_PRED_DIR_, load_as=task)
    model.load_adapter('Pretrained_Adapters_NLI/'+_PRETRAINED_ADAPTER_, load_as=task)

    model.set_active_adapters(task)
    model.train_adapter(task)


    # create trainer and train -------------------------------------------

    trainer = AdapterTrainer(
        model           = model,
        args            = training_args,
        train_dataset   = Train,
    )
    trainer.args._n_gpu = _NO_GPUS_

    trainer.train()
    
    
    # get predictions ----------------------------------------------------
    
    
    ignore_keys = None
    if is_encoder_decoder:
        ignore_keys = ['encoder_last_hidden_state']

    results            = trainer.predict(Test , ignore_keys = ignore_keys)
    author_predictions = compute_author_predictions_nli(baseTest, results.predictions, task, len(class_dict), nli_label2id)

    # report metrics 

    report = {'soft': classification_report(author_predictions['true'], author_predictions['pred_soft'], digits=4), 
               'hard': classification_report(author_predictions['true'], author_predictions['pred_hard'], digits=4)}

    f1s_soft.append( f1_score(author_predictions['true'], author_predictions['pred_soft'], average = 'macro') )
    f1s_hard.append( f1_score(author_predictions['true'], author_predictions['pred_hard'], average = 'macro') )
    
    print("Results with split " + str(split + 1) + ":\n")
    print("soft voting:\n", report['soft'], '\n')
    print("hard voting:\n", report['hard'])


    # get predictions with Logistic Regression----------------------------

    resultsTrain = trainer.predict(Train, ignore_keys = ignore_keys)
    author_predictions_LR = compute_author_predictions_nli_LR(Train, baseTest, resultsTrain.predictions, results.predictions, task, len(class_dict))
    
    f1s_soft_LR.append( f1_score(author_predictions_LR['true'], author_predictions_LR['pred_soft'], average = 'macro') )
    f1s_hard_LR.append( f1_score(author_predictions_LR['true'], author_predictions_LR['pred_hard'], average = 'macro') )
    
    # report metrics 

    report_LR = {'soft': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_soft'], digits=4), 
               'hard': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_hard'], digits=4)}

    print("Results with split " + str(split + 1) + " using LOGISTIC REGRESSION:\n")
    print("soft voting:\n", report_LR['soft'], '\n')
    print("hard voting:\n", report_LR['hard'])

     
    
    # save predictions ----------------------------------------------------
    
    DIR = 'results/' + _DATASET_ + '/' + _LANGUAGE_ + '/' + _PRED_DIR_ + '/' + str(_NUM_AUTHORS_) + '_authors/test_split_' + str(split + 1) + '/'
    if not os.path.exists(DIR):
        os.makedirs(DIR)

    with open(DIR + 'predictions.pickle', 'wb') as f:
        pickle.dump(author_predictions, f)
    
    with open(DIR + 'predictions_LR.pickle', 'wb') as f:
        pickle.dump(author_predictions_LR, f)

    with open(DIR + 'report.txt', 'w') as f:
        f.write("soft voting:\n" + report['soft'] + '\n\n')
        f.write("hard voting:\n" + report['hard'])
        
    with open(DIR + 'report_LR.txt', 'w') as f:
        f.write("soft voting:\n" + report_LR['soft'] + '\n\n')
        f.write("hard voting:\n" + report_LR['hard'])
# Out:
# Some weights of the model checkpoint at ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli were not used when initializing BartAdapterModel: ['classification_head.out_proj.bias', 'classification_head.dense.weight', 'classification_head.out_proj.weight', 'classification_head.dense.bias']
# - This IS expected if you are initializing BartAdapterModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BartAdapterModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /001/usuarios/isaac.bribiesca/anaconda3/envs/NLP/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 12800
#   Num Epochs = 10
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 16000
#     <div>
#
#       <progress value='2763' max='16000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 2763/16000 19:50 < 1:35:07, 2.32 it/s, Epoch 1.73/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-500
# Configuration saved in checkPointsUniPELTNLI/checkpoint-500/hateSpeech/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-500/hateSpeech/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-500/hateSpeech/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-500/hateSpeech/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-500/hateSpeech/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-500/hateSpeech/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-178000] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-1000
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1000/hateSpeech/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1000/hateSpeech/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1000/hateSpeech/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1000/hateSpeech/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1000/hateSpeech/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1000/hateSpeech/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-178500] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-1500
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1500/hateSpeech/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1500/hateSpeech/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1500/hateSpeech/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1500/hateSpeech/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1500/hateSpeech/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1500/hateSpeech/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-179000] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-2000
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2000/hateSpeech/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2000/hateSpeech/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2000/hateSpeech/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2000/hateSpeech/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2000/hateSpeech/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2000/hateSpeech/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-179500] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-2500
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2500/hateSpeech/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2500/hateSpeech/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2500/hateSpeech/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2500/hateSpeech/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2500/hateSpeech/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2500/hateSpeech/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-180000] due to args.save_total_limit

# %%
# report statistics

print('Soft results: ', f1s_soft)
print('\nHard results: ', f1s_hard)

f1s_soft = np.array(f1s_soft)
f1s_hard = np.array(f1s_hard)

FewShot_Results = {'soft': [f1s_soft.mean(), f1s_soft.std()], 'hard': [f1s_hard.mean(), f1s_hard.std()]}

print('\n\nSoft statistics: ')
print('\t[avg, std]:', FewShot_Results['soft'])

print('\nHard statistics: ')
print('\t[avg, std]:', FewShot_Results['hard'])
# Out:
# Soft results:  [0.63942308 0.6296667  0.65877158 0.6296667  0.63985594]
#
# Hard results:  [0.64968472 0.59983994 0.64968472 0.6296667  0.65986395]
#
#
# Soft statistics:
# 	[avg, std]: [0.6394767994079457, 0.010629310454208363]
#
# Hard statistics:
# 	[avg, std]: [0.6377480028143777, 0.02133735768834956]

# %%
# report statistics

print('Soft results: ', f1s_soft_LR)
print('\nHard results: ', f1s_hard_LR)

f1s_soft_LR = np.array(f1s_soft_LR)
f1s_hard_LR = np.array(f1s_hard_LR)

FewShot_Results_LR = {'soft': [f1s_soft_LR.mean(), f1s_soft_LR.std()], 'hard': [f1s_hard_LR.mean(), f1s_hard_LR.std()]}

print('\n\nSoft statistics with LOGISTIC REGRESSION: ')
print('\t[avg, std]:', FewShot_Results_LR['soft'])

print('\nHard statistics with LOGISTIC REGRESSION: ')
print('\t[avg, std]:', FewShot_Results_LR['hard'])
# Out:
# Soft results:  [0.64912281 0.62817807 0.65945513 0.6296667  0.63869932]
#
# Hard results:  [0.64912281 0.5985548  0.63985594 0.61984794 0.64968472]
#
#
# Soft statistics with LOGISTIC REGRESSION:
# 	[avg, std]: [0.6410244050702752, 0.011871877898991207]
#
# Hard statistics with LOGISTIC REGRESSION:
# 	[avg, std]: [0.6314132404169915, 0.019658017566982468]

# %% [markdown]
# ## Training with all

# %%
from tools.DataLoaders import DatasetPANnli

baseTest.get_all_data(_TWEET_BATCH_SIZE_, tokenizer, _MAX_SEQ_LEN_, _PREPROCESS_TEXT_, NLI=True, label_hyp=label_hyp, nli_label2id=nli_label2id)

Test  = DatasetPANnli(baseTest)
Train = DatasetPANnli(baseTrain)
# Out:
# Reading data...
#     Done
# Preprocessing text...
#     Done
# Tokenizing...
#     Done
# Merging data...
#     Done
#
# Total Instances: 96000

# %%
from transformers import TrainingArguments

samples = 4 * _NUM_AUTHORS_ * int(100 / _TWEET_BATCH_SIZE_)
_LOGGING_STEPS_ = int(samples / _BATCH_SIZE_)

training_args = TrainingArguments(
    learning_rate               = _LEARNING_RATE_,
    num_train_epochs            = _EPOCHS_,
    per_device_train_batch_size = _BATCH_SIZE_,
    per_device_eval_batch_size  = 200,
    logging_steps               = _LOGGING_STEPS_,
    output_dir                  = _OUTPUT_DIR_,
    save_total_limit            = 5,
    overwrite_output_dir        = True,
    remove_unused_columns       = False,
)

# %%
from transformers import AutoAdapterModel, AutoModelForSequenceClassification
from tools.DataLoaders import DatasetCrossValnli
from transformers import AdapterTrainer
from tools.Testing import compute_author_predictions_nli, compute_author_predictions_nli_LR
from sklearn.metrics import f1_score, classification_report
import pickle


# train

task = label_name

# initialize model ---------------------------------------------------

static_head_model = AutoModelForSequenceClassification.from_pretrained(_PRETRAINED_LM_)
static_head_model.add_adapter(task, config = _ADAPTER_CONFIG_) 
static_head_model.save_adapter('aux_adapter_'+_PRED_DIR_, task)

model = AutoAdapterModel.from_pretrained(_PRETRAINED_LM_)
model.load_adapter('aux_adapter_'+_PRED_DIR_, load_as=task)
#model.load_adapter('pretrained_adapter_NLI', load_as=task)

model.set_active_adapters(task)
model.train_adapter(task)


# create trainer and train -------------------------------------------

trainer = AdapterTrainer(
    model           = model,
    args            = training_args,
    train_dataset   = Train,
)
trainer.args._n_gpu = _NO_GPUS_

trainer.train()


# get predictions ----------------------------------------------------


ignore_keys = None
if is_encoder_decoder:
    ignore_keys = ['encoder_last_hidden_state']

results            = trainer.predict(Test , ignore_keys = ignore_keys)
author_predictions = compute_author_predictions_nli(baseTest, results.predictions, task, len(class_dict), nli_label2id)

# report metrics 

report = {'soft': classification_report(author_predictions['true'], author_predictions['pred_soft'], digits=4), 
           'hard': classification_report(author_predictions['true'], author_predictions['pred_hard'], digits=4)}

print("Results:\n")
print("soft voting:\n", report['soft'], '\n')
print("hard voting:\n", report['hard'])


# get predictions with Logistic Regression----------------------------


resultsTrain = trainer.predict(Train, ignore_keys = ignore_keys)
author_predictions_LR = compute_author_predictions_nli_LR(baseTrain, baseTest, resultsTrain.predictions, results.predictions, task, len(class_dict))

# report metrics 

report_LR = {'soft': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_soft'], digits=4), 
           'hard': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_hard'], digits=4)}

print("Results using LOGISTIC REGRESSION:\n")
print("soft voting:\n", report_LR['soft'], '\n')
print("hard voting:\n", report_LR['hard'])
# Out:
# Some weights of the model checkpoint at ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli were not used when initializing BartAdapterModel: ['classification_head.out_proj.weight', 'classification_head.out_proj.bias', 'classification_head.dense.bias', 'classification_head.dense.weight']
# - This IS expected if you are initializing BartAdapterModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BartAdapterModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /001/usuarios/isaac.bribiesca/anaconda3/envs/NLP/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 144000
#   Num Epochs = 10
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 180000
#     <div>
#
#       <progress value='6161' max='180000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  6161/180000 47:27 < 22:19:39, 2.16 it/s, Epoch 0.34/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5120</td>
#       <td>0.614800</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-500
# Configuration saved in checkPointsUniPELTNLI/checkpoint-500/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-178000] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-1000
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1000/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-178500] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-1500
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1500/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-1500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-1500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-179000] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-2000
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2000/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-179500] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-2500
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2500/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-2500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-2500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-180000] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-3000
# Configuration saved in checkPointsUniPELTNLI/checkpoint-3000/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-3000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-3000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-3000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-3000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-3000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-3500
# Configuration saved in checkPointsUniPELTNLI/checkpoint-3500/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-3500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-3500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-3500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-3500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-3500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-4000
# Configuration saved in checkPointsUniPELTNLI/checkpoint-4000/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-4000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-4000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-4000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-4000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-4000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-4500
# Configuration saved in checkPointsUniPELTNLI/checkpoint-4500/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-4500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-4500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-4500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-4500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-4500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-5000
# Configuration saved in checkPointsUniPELTNLI/checkpoint-5000/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-5000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-5000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-5000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-5000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-5000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-5500
# Configuration saved in checkPointsUniPELTNLI/checkpoint-5500/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-5500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-5500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-5500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-5500/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-5500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to checkPointsUniPELTNLI/checkpoint-6000
# Configuration saved in checkPointsUniPELTNLI/checkpoint-6000/gender/adapter_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-6000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-6000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-6000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsUniPELTNLI/checkpoint-6000/gender/head_config.json
# Module weights saved in checkPointsUniPELTNLI/checkpoint-6000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsUniPELTNLI/checkpoint-3500] due to args.save_total_limit

# %%
print("Results:\n")
print("soft voting:\n", report['soft'], '\n')
print("hard voting:\n", report['hard'])
# Out:
# Results:
#
# soft voting:
#                precision    recall  f1-score   support
#
#            0     0.7960    0.8717    0.8321      1200
#            1     0.8582    0.7767    0.8154      1200
#
#     accuracy                         0.8242      2400
#    macro avg     0.8271    0.8242    0.8238      2400
# weighted avg     0.8271    0.8242    0.8238      2400
#
#
# hard voting:
#                precision    recall  f1-score   support
#
#            0     0.7824    0.8900    0.8327      1200
#            1     0.8725    0.7525    0.8081      1200
#
#     accuracy                         0.8213      2400
#    macro avg     0.8274    0.8213    0.8204      2400
# weighted avg     0.8274    0.8213    0.8204      2400

# %%
print("Results using LOGISTIC REGRESSION:\n")
print("soft voting:\n", report_LR['soft'], '\n')
print("hard voting:\n", report_LR['hard'])
# Out:
# Results using LOGISTIC REGRESSION:
#
# soft voting:
#                precision    recall  f1-score   support
#
#            0     0.8044    0.8533    0.8281      1200
#            1     0.8438    0.7925    0.8174      1200
#
#     accuracy                         0.8229      2400
#    macro avg     0.8241    0.8229    0.8228      2400
# weighted avg     0.8241    0.8229    0.8228      2400
#
#
# hard voting:
#                precision    recall  f1-score   support
#
#            0     0.7854    0.8783    0.8293      1200
#            1     0.8620    0.7600    0.8078      1200
#
#     accuracy                         0.8192      2400
#    macro avg     0.8237    0.8192    0.8185      2400
# weighted avg     0.8237    0.8192    0.8185      2400

# %%
model.save_adapter('Pretrained_Adapters_NLI/'+_DATASET_+'_'+_PRED_DIR_, task)
