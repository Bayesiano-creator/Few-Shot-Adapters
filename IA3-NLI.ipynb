# %% [markdown]
# ## Set Global Seed

# %%
import os
import random
import numpy as np
import torch
import transformers

def set_all_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
seed = 260615
set_all_seeds(seed)

print("The global seed " + str(seed))
# Out:
# The global seed 260615

# %% [markdown]
# ## Hyperparameters

# %%
# LANGUAGE

_LANGUAGE_         = 'es'
_DATASET_          = '2019'

# %%
# MODEL CLASSIFICATION

_PRETRAINED_LM_    = 'vicgalle/xlm-roberta-large-xnli-anli'
_PREPROCESS_TEXT_  = True
_TWEET_BATCH_SIZE_ = 5
_ADAPTER_CONFIG_   = transformers.IA3Config()
_MAX_SEQ_LEN_      = 150

# %%
# TRAIN

_OUTPUT_DIR_       = 'checkPointsIA3NLI'
_LOGGING_STEPS_    = 50
_NUM_AUTHORS_      = 512
_K_FOLD_CV_        = 5
_NO_GPUS_          = 1
_BATCH_SIZE_       = int(8 / _NO_GPUS_)
_EPOCHS_           = 10
_LEARNING_RATE_    = 1e-5

# PREDICTIONS

_PRED_DIR_         = 'IA3NLI'

# %% [markdown]
# ## Other parameters

# %%
# LABEL DICTONARIES -----------------------------------------------------------------------

# 2015

age_dict  = {'18-24': 0, '25-34': 1, '35-49': 2, '50-XX': 3}
ageEN_hyp = {0: '18-24', 1: '25-34', 2: '35-49', 3: '50-XX'}
ageES_hyp = {0: 'La edad de esta persona es entre 18 y 24 años', 
             1: 'La edad de esta persona es entre 25 y 34 años', 
             2: 'La edad de esta persona es entre 35 y 49 años', 
             3: 'La edad de esta persona es más de 50 años'}

# 2017

gender_dict    = {'female': 0, 'male':   1}
varietyEN_dict = {'australia': 0, 'canada': 1, 'great britain': 2, 'ireland': 3, 'new zealand': 4, 'united states': 5}
varietyES_dict = {'argentina': 0, 'chile': 1, 'colombia': 2, 'mexico': 3, 'peru': 4, 'spain': 5, 'venezuela': 6}  

genderEN_hyp  = {0: 'I’m a female', 1: 'I’m a male'}
genderES_hyp  = {0: 'Mi nombre es María', 1: 'Mi nombre es José'}

# 2019

bots_dict  = {'human': 0, 'bot': 1}
botsEN_hyp = {0: 'This is a text from a person', 1: 'This is a text from a machine'}
botsES_hyp = {0: 'Humano', 1: 'Bot'}

# 2020 

fakeNews_dict  = {'0': 0, '1': 1}
fakeNewsEN_hyp = {0: 'This author is a normal user', 1: 'This author spreads fake news'}
fakeNewsES_hyp = {0: 'Este autor es un usuario normal', 1: 'Este autor publica noticias falsas'}

# 2021

hateSpeech_dict  = {'0': 0, '1': 1}
hateSpeechEN_hyp = {0: 'This text does not contain hate speech', 1: 'This text expresses prejudice and hate speech'}
hateSpeechES_hyp = {0: 'Este texto es moderado, respetuoso, cortés y civilizado', 1: 'Este texto expresa odio o prejuicios'}

# %%
# SET LANGUAGE DICTIONARIES --------------------------------------------------

if _LANGUAGE_ == 'en':
    age_hyp        = ageEN_hyp
    gender_hyp     = genderEN_hyp
    variety_dict   = varietyEN_dict
    fakeNews_hyp   = fakeNewsEN_hyp
    hateSpeech_hyp = hateSpeechEN_hyp
    bots_hyp       = botsEN_hyp 

elif _LANGUAGE_ == 'es':
    age_hyp        = ageES_hyp
    gender_hyp     = genderES_hyp
    variety_dict   = varietyES_dict
    fakeNews_hyp   = fakeNewsES_hyp
    hateSpeech_hyp = hateSpeechES_hyp
    bots_hyp       = botsES_hyp
    
    
# SET LANGUAGE AND DATASET PARAMETERS ----------------------------------------
    
if   _DATASET_ == '2015':
    label_idx  = 2
    class_dict = age_dict
    label_name = 'age'
    label_hyp  = age_hyp
    
elif _DATASET_ == '2017':
    label_idx  = 1
    class_dict = gender_dict
    label_name = 'gender'
    label_hyp  = gender_hyp
    
elif _DATASET_ == '2019':
    label_idx  = 1
    class_dict = bots_dict
    label_name = 'bots'
    label_hyp  = bots_hyp
    
elif _DATASET_ == '2020':
    label_idx  = 1
    class_dict = fakeNews_dict
    label_name = 'fakeNews'
    label_hyp  = fakeNews_hyp
    
elif _DATASET_ == '2021':
    label_idx  = 1
    class_dict = hateSpeech_dict
    label_name = 'hateSpeech'
    label_hyp  = hateSpeech_hyp

# %%
from transformers import AutoTokenizer, PretrainedConfig

tokenizer = AutoTokenizer.from_pretrained(_PRETRAINED_LM_)
vocab = tokenizer.get_vocab()

config             = PretrainedConfig.from_pretrained(_PRETRAINED_LM_)
nli_label2id       = config.label2id
is_encoder_decoder = config.is_encoder_decoder
# Out:
# You are using a model of type xlm-roberta to instantiate a model of type . This is not supported for all configurations of models and can yield errors.

# %% [markdown]
# ## Datasets

# %%
# GET AUTHORS AND LABELS -----------------------------------------------------

from tools.DataLoaders import BasePAN

baseTrain  = BasePAN(Dir        = 'data/' + _DATASET_,
                     split      = 'train',
                     language   = _LANGUAGE_,
                     label_idx  = label_idx,
                     class_dict = class_dict,
                     label_name = label_name)

baseTest   = BasePAN(Dir        = 'data/' + _DATASET_,
                     split      = 'test',
                     language   = _LANGUAGE_,
                     label_idx  = label_idx,
                     class_dict = class_dict,
                     label_name = label_name)

# %%
# GET K-FOLD SPLITS -----------------------------------------------------

crossVal_splits = baseTrain.cross_val(_K_FOLD_CV_, _NUM_AUTHORS_)

crossVal_splits[0][0]
# Out:
# ['c270cc9a3be185547804c10cc2985e3c',
#  'ef8a2d99b01c8a024172c202951e5893',
#  'abf5cbfa07bf8973f3a2d8d3052a03e8',
#  'fb29e93c9bdb0dc827f3d2d5751fad2a',
#  '52a11f8880a98760047362d065d08799',
#  '21fd2a8aa5eb8e49c3b81c2382f3d6b6',
#  'd6ffa20cdf6a6d6185b5a8bc26e8c93d',
#  'bc2c800ebafce8e75690252a53c4cca7',
#  '6631827a81978052c88294ee9be6afe5',
#  'e2296ddebe34fbc26966f638739abbf0',
#  '5770c9aa6bf073e0674a679b1f5ee88b',
#  '62586920282fe7e5df630a439488029c',
#  '335cc0daaf8dbb3772b03e077a198d08',
#  '9e5a10b5c50af5da00417026ad8ad027',
#  '5d17b889e9c842795782f0dee18ca2ed',
#  '475b7d7073d9f78fd6fdb7d96692316b',
#  '3ce0b034475e1fdc4486b0d7e2faec17',
#  '9b84e175729d9f4f25cf53de10183f65',
#  '8a50d1f5adc80cc2178f18613d3adf21',
#  '9bb3ecf9724c0c85a77281f9822a46f3',
#  'f8627e5420297aee1fcea32b62e40a35',
#  'f605a79453c32ba2d99bfd361d39deed',
#  'd7f0fe2d08596dccfb259474a601e66c',
#  'cec0c0d6ed8bb614563935d3a0a74df3',
#  'ad41196384738c373f5f2f5332a1ee61',
#  'a586df8faf679f44947cd9b91ff1d28',
#  '2ffda3b2e84a6036d38be5168b3e0360',
#  '599e39dba284dc00b0826ecd2fe1ff1d',
#  'abc451edcb60fc53d9d967c8871b92f6',
#  '35c14a799011a307767f5b94bb508b4d',
#  'eb2907ee4bcb2dcec512436552c365a2',
#  '8ad3154ad546bedffd405987b3df9936',
#  '6e17ae0995e8ef564cb7575a8d0b376c',
#  'e80ba521559a5a7c30a5e5277bb3bffb',
#  '11ab6adedfa5d496156a0658549f88cf',
#  '6191de088282820c855f73847c52832',
#  'c1fcf0cc00d36eff44eaffb61bcdd1fc',
#  'cfe408917196def8cdbce6ad5a0d0561',
#  '62cb4de958aded36c4aa035424db6859',
#  '23d4e1bd1992220e946a4c26fe49b824',
#  'cab00e195b2502457a76c8e4ff56ea61',
#  '104e6a4ca41aea909f429d115a32326c',
#  '2a8b22020de0c8332b12057ecde52b09',
#  '2a664dae0f17e380c2fa8f7246cacc85',
#  'c8f4c6c36b22bca0ee0332d9dd9d9234',
#  '870ac01ef59ddbe1100e8aacad7d5854',
#  '9b26cbc27a7770bba02e07b0f6d01227',
#  'c62cf51f5edab3e34c6d546d8dcd5001',
#  '76fa146e866dc7f56cf61fc7a68d0b52',
#  '4d4b98de9698e670afde14c37ecba11f',
#  'fc4a19941dccbc1884946c888620a293',
#  'e6bc806f492463f4da775fbfbe005108',
#  '5685f048dcae2e55d7543917e6224656',
#  '581ba36d2bcee0f189906903b94542c2',
#  'd54194cbb51df207e5cccccef5cc7e38',
#  '6ae5b4e52c840fb2bd9c1f3c532ec78c',
#  '53e654e0477c9e64eb718d2154805523',
#  'ac031537c195aa410d8d795b4d6b2240',
#  '3d43b142be94a9ffa6b54f04425d901e',
#  '625532826bb0eca558653eef596fae8f',
#  '8069c6ba4247bf32030db34636365832',
#  'c045e81850cfae76d26c4d93663ce81d',
#  'e05d00a2fc148711f0ff9767c7da6f1a',
#  '43fb0cc69f1aefabeaade3868ca2a3ac',
#  'f19e301939eab3d5e9c085c4f471479c',
#  'd5508525f1b947db9ef9d3ee09c05231',
#  'd645eb331b869f19659cdc2b8d81a4cd',
#  '491c8e6d828104f9fe383685240c0984',
#  'ed0c4c8edb789a638d3430b65ca977f3',
#  '57988b69aa3ca20b4c6e31f7744173e3',
#  'e580e496b24791a0d98c2f1096d75e1f',
#  'c2bd80566ce1106885291e10b00d4aeb',
#  '33ceddb0fb1a998617443d8e3c41e84c',
#  '26395c3e3010dc76a87a715bb578f831',
#  'da92b04d51ffbbf5a8ff6b93f4270ee1',
#  '79a7ec52f46da5647f804fd5c4ed2210',
#  'f00dfc75f7e4f9949a310e3e83cc2f4a',
#  '17d13018e6d5cd1822015b4c7d50e8a2',
#  '1e64c9e32e18e6c84d3497885dfa9284',
#  '82482ac436faae3344b4be45a3d0ec8c',
#  '20a80ab7d4b141257d8668b2db9aab6e',
#  '68769021bfd447b7c8ec4f678570bc63',
#  '2a167bc99e5dd5f5043f3c31e86aca57',
#  'da54bb7a2178bce94a6d03dd87edceb9',
#  'd27e03dbc5241825f8ca3b431ca7a4c6',
#  '867bd8bcd42a88f862c0898ad8a14fd9',
#  'c833a4a14b059afb2b1f29700ab02b6c',
#  'bdc55b935cdf7bfc2a72b127928d908e',
#  'e1a782c445fb8ba692a0e9a6049f1cf',
#  '435328547bbdcc29698ba02015bc569',
#  '5c0e50067b41b94f6dd60813e02ef1b2',
#  'e381ba652c9b8f461f5b7de6dd8611e4',
#  '9f18f372f8796a61049e240d6b9cec55',
#  'de9ffa280fed861c8f41d0a77a04a63e',
#  '3c1825b49e0a3dba267b3b335ed9c528',
#  '7728e1845212ed82e638fbf3e45605be',
#  'b1a6d627a05153c814ae4994bf4c0bd7',
#  '135816270ee29c2505aa6d148c8cee63',
#  'a431093d15ddce205f19234740cc24d7',
#  '87ef8532e6dcf5e9635ad27316a3e290',
#  'a2a62f2c78b3a392d692818b9a1b9a42',
#  '1e6ccae7fd6d7c93e4e96efde2b2abc8',
#  '17cb8cea2927b2063d74183485de8cfa',
#  '1981c251af7ffeba7487f8ca6194a1ab',
#  'f1c460ef9b48a76f04cf0e1efbb8b4ef',
#  '843ae5ef16426bed9b081dab1ffc463',
#  'dcd4e1d3942de7a4592e3714922176ff',
#  '9200e0e8dad6219f0de8737d196fc635',
#  'e28aea1df449cf25b31990d623615715',
#  '812423b6bab140f1d2a4947bc9ba60a7',
#  'dfdfcb54dd13a841ea648c5e94ad51ca',
#  'b4d48b320f086e336c60ad84ab3bc045',
#  '8bb843ead1ad78bb3e987b6dd08e669e',
#  'b79d03ba4be06f43e0e84a796c90b92a',
#  'a43b8c4cf2a690ee7714ab47135d1eb6',
#  '2e68cb78392b859b4a920e7703f0cb8',
#  '9cce41dd9409fbc03796ac83da2a5a3e',
#  '90b36e787e7657be1f2e63521bbffa61',
#  'e5b2622068e8ff081946651a021ba4fb',
#  'be583f019ee57470ce5319dc512dba40',
#  'f5daf4ef6c85422ee035aee728b306e1',
#  '93686112806b15b97b874254b5950d1b',
#  '74377704d8998708cc90b6df7c7f6c61',
#  '784536a5a2bf48626d98b762023b4520',
#  'c3f0b0445f5353e2731ade13886a6dab',
#  'b24c6a6094dd4a38397139dc5bc9dd36',
#  'c43311914c70e05084b78b2553538c53',
#  'ab847544d7276c3d2e0358a83c56a160',
#  'bfc407a469331fada54f8fc12de4b6b5',
#  'aa8ead4894011ef7b21c7a2a8f68ad4',
#  '274441a642ea5e3f0d416d2912da38b9',
#  '6850ee6cead9445a7f504af136feb948',
#  'b8090f5fc034c5f1e29f482bb6af08dc',
#  '26014673277e5a1e37773f6f1feadd35',
#  '9a66ba898ff227801b47a5197eaada88',
#  '9c80f49bd1a64923cede98e016901a38',
#  'd641c265b7ba5dcf6be3da824cb2dcdc',
#  'de2b6913cc7fdb04548e929708e9c52b',
#  '375fa2f9e6cd6f828ee9009f166817b5',
#  '5aa202896156481f7692b568320fd8d8',
#  '77884489f75da435ff888299e1a38d75',
#  'ca4ce1d738ec3b91d216c15a2a7c3267',
#  'f8848109b0b5a133a3879b0010a8154d',
#  '1f53ac812eb1cb6698fb70099084b0a6',
#  'a0a3e0f623bd8d4677ced8f209566d85',
#  '8b9d8109dad90ad5b739c47b1e405fe0',
#  '8b2384dfa0e01a9efbb139b252b2f940',
#  'fd7a4ff5f8208134ce80f4745d6cb560',
#  '4b741043ef56310d4624e02a5c117992',
#  'cfab46e3654f9b8229de70cdc6a4464f',
#  'fbb8807774564d2cf2d5642f4e9e5466',
#  'a447b76e25f9aec6b11fdf2b1d385c85',
#  'a2f502b187bfc6531915cf55bf129bc7',
#  '513fb65a02cdcbb20efd37a8b5027e8a',
#  '2a4fcc6ca6387b848d6f068398c951f0',
#  '4c22607317249621bf430f0bba9c46b7',
#  'eb5abb8b88f57031b34f8df3e377993b',
#  '418157977729ad3820a921b6ab80063d',
#  '6df4294152c3b1e48f3e9a1ae13e2665',
#  'fad9f50742fbb4754ffea1faed468450',
#  'e9ae144e0c042257656c479d066e0160',
#  'a16502cec394c807416645950c23f638',
#  '84662ed2b77306e5440009bb4c21788c',
#  '27ee8a3a3287e7a7182ed6695eb92f77',
#  'f4b264a6d8fa1fb0a29d48698a14a757',
#  '9df4c56d2920742f1f19f7b5c002990d',
#  'fd3e27d4fa71ef463f677f071ddb517e',
#  'd67f436cf8b8137c06bf8a0f196d895f',
#  'f103c7168db6d6f195bd3dd9a51e2afe',
#  '72472a9c1db1190f972c0685c17e6967',
#  'b34a7025394b977d5e72224385338dbf',
#  '3495f1797656098e13418317feae6ebe',
#  'ff35d218ee959f304b911340bd785848',
#  'f705e012c8ff0665123d5e4170ab4192',
#  'd5ead7ea400c2ab2b6a0696d38d2b6a0',
#  '46cadf15e21608436cdf4ac471205cc',
#  '4d1e7be7a5701cfb2e5e7e9a10104ecf',
#  '83eab784b2939a8980fd05ef163822bc',
#  'fafcef671e147d746b456ccf8f078773',
#  'ea8980730ca26904535fbf525ab113f',
#  'c9d9071279166b4cb3d52d4f0f4b34c9',
#  '98f6f14db182ad91fa502f4b591761ba',
#  '624fe6ef9c64c38638a866df2dd98b0b',
#  '6108f04f4e60d3696fe4ed80da0a8de',
#  'ef5975b7b9009d994ce8e6e12b4fd5',
#  '4de600dbf91a912522d66777bd8a92eb',
#  'c71157d9cd43a9fd008fe72c25e1eabb',
#  '91c9da9c08a45d67cff248697ba8567f',
#  'b9632a04d69d673c7ecddd3ee526719b',
#  'f455f7a2ce162564d44ae1eb989e6685',
#  '72a19715c0d6fc6a783ec9bed6b49085',
#  '33fd5990d027a011efe6774e969b2b8c',
#  '55c0157ea6b9a9b9c93831a045e60528',
#  '3b349e51075cb9e4453b65bdccfee039',
#  '41fa0b16b1e4b0c2885069569ae1c454',
#  'd69d28298044245c5aec32bce9b74907',
#  'f7359c0c1f27b0c1b6a2bfcf2070ccec',
#  'cfa825880b100d8b2c90126e4031bb75',
#  '9bbaabdb38f985abc6bdf033c58d8f3e',
#  'cd5c1a99889e43345b7c080794340508',
#  '948d2f6a6c824383f9506a37b5266888',
#  '945c719e4efc11a24730e00e960b9f60',
#  'a9ef775f50971a4e2f1cf0ceb616d0b8',
#  'd2a26f3e410145cff1f6636f9a1f42d3',
#  'ae08278ec4a31a7f11a9c1f13e11a610',
#  '8ea4ad5d748285935996a6308b0de69d',
#  '8b2d2627c1e1942dfd0038dc722edb13',
#  '4f25c01ec91e36f0bd6b42f9ef3ee603',
#  '23c711b89990b80d959f04b269b14be9',
#  '21e67d6ca59bd54d861bbf2f12876e14',
#  '5e6cbd820f4535efada804dea8314ad3',
#  '220740bd516bbd0d5d0806bafcde6738',
#  'ef44abfcbcbcb142253b28411bb4bd6c',
#  '8a9dde22ee3c2d606bfe81874dc763d4',
#  '31961c615439e8c85994036a3931219',
#  '267d5422041159adf88df2c92d060e94',
#  'cce0299dcfd56e04aa6e37d8106a4fe5',
#  'a6c30b558d761001cf73373d7392c30d',
#  '92cd028fa46a3432e1e8d6d316aaf9e3',
#  '6609a238e03831d25952ea01c7811ddc',
#  '2c09f06756337ae1e1f47e5583c37ee1',
#  '7c8d75a701f0d362443096999397e481',
#  '4a5bd15ff1e313fe185212f69ee28009',
#  '9af7afec6ad0900b05e8318c72116e3e',
#  'e85b376054ee9cfa7c12700f9fe355e2',
#  '4e1cad4ca549f6a5e0cf88e935f929d4',
#  '8acbffc766abf289b17df19d7be95437',
#  '80d780b4b212202ba97f683abed3b4ad',
#  '4e35aa8a02c0e38d57b900984f5a263f',
#  'e0fdd580056259f645f9e2c15cc6b7d1',
#  '3058fd458c25a0d99ce9f0a87679eb7a',
#  '8bbc377c0bdfd87eeee7f9f26b53171c',
#  '91189bb832d166a060f35d327a89f02c',
#  '5307371dc8f0b800cbad3df0215a8712',
#  '5f7b63f6c519a73fe79e5a164a3e2bae',
#  '7de969e004ca982ff3383bfd1f7e4032',
#  '83f3e81aac90e8df24862be22c15c553',
#  '4e2b8fcf8f377ca7998118ff0f10e95d',
#  'ad1b1c141ce61ef655e94755df4a07af',
#  '62b68a377e8b16d491d6308b569ecba1',
#  'cc7503e4a26d5be18c8fa919d13bc047',
#  '470159829a6ed2a4b5d546de64e92183',
#  '6d597db2edc77cd07d00eed83145c86d',
#  '6c49c91f48ed70d16cd01d7b18e0a613',
#  '579c8db702e24ad63d895f9e1c4a4b61',
#  '465d62cb96234de7cb042f70589a5cad',
#  'f5cfe771508ed08869c1fb46a89e9609',
#  'fef93b494a395ab0f3df4449ce929804',
#  '8a37b6969ecad32ebd7cfa07db3a5ada',
#  '529afc43c81868c8a457a0f1c023a9ef',
#  '31717025e113d6ff84026359a57f6806',
#  '6dc5c69ff79a097c43d5dcf6ab7df864',
#  'b554e03baf203ee035bf7569cdd15561',
#  '53a4e1d0748cf1609d15846a45bf12f8',
#  'c018efad473677f73654ec5576d63f67',
#  'ba643007856d754b03ba36c15fda60f0',
#  '39bb6ce0dd8191fb6c25e1c07397ae51',
#  'a5ea4f08d0dca2a3d5dcf75c908ce5f6',
#  '1595e6c859e00ec1c10831c43c6e8bc2',
#  '78949b6255f5aa8f1c91dab1065f6a15',
#  'd9bdab07e24113226c694e90157acb98',
#  '2aabcc3f68ff2595b4182fd502d889ba',
#  '4c541f0473d4c364d7d6996f6422cf97',
#  '5995da108cba354c2903ad18d19eb8bb',
#  'd9dd7088b6589e22a103c74a29444fac',
#  '83202b82df844abbafd41cbd56e60abf',
#  '353352a475ac7bf44d5195f196c95d0a',
#  'b02112ae20aabd10fdc95a509fa01fae',
#  'f54010bf22cb154f0013a6932357bf8e',
#  '768cbc5c47df4ea650bc5ec9a459b5a7',
#  'd06e41d0cb5267c628c065ff97698d5d',
#  '14e8f54b00ee41b14798c4f38a038e30',
#  '784b4bbb282981672077411e835e0334',
#  'e2140b2e8e06d8368ebfe8d7680acbd2',
#  '931260813f87afb72904a6a4b53e27e1',
#  'f4fceb2cd13c470fab456d1b27f3c8bf',
#  '43a19d8e64bd19af8855df00217dd48',
#  'a3095ce6b28d0ea1d0b4bb9a7dc79532',
#  '2c2bb38f9b974fa0ca8b30a1e09bfa7d',
#  '7d3ed9193074d1925ecb17eac8c73a6f',
#  'bc50b53e4032063e323cbb1ba882b132',
#  '9d0be12a4662982452f8595b7bc006ba',
#  'd1f0acc1a544086300834fe999cbb0bb',
#  'c77f05a8e40faa3c93c782d76592e44',
#  '855c9ee7a6c0e1f1e73b3500a401b2f',
#  '2b9066d5e0bdde41a2d235abf42c00ab',
#  'debb1500d36399b7eafb518580932a62',
#  '9f60afaa43c0e3a56c5c522f45beb501',
#  '67206f559c8ed8eacf13e5c94bf37219',
#  'db5d8d1cc8769e73aef53f53b2d833e2',
#  'e561853470c798d07dd1f79576cccf37',
#  '3ead5fb4e0b09ef753e3eefe57dc0c6b',
#  'bce7f95ee1a8e878fd512d604d3aa68e',
#  'd2fd5c1959db1e802c923a61e5a83c72',
#  '72f763142df2aad6c9221627bd5a89a',
#  'e1caeacde867f515f189a8cd63307103',
#  'bc39b19431513cd8bf6081fd06383f31',
#  'ab254560053389f4cfac91fdcc9d978c',
#  'b1947988dacf1d1ca9e5fea21696b756',
#  '94d86242c9af2121f2016bf9a7c9d22c',
#  '52fc0644b94c2183c9a239085fc5317c',
#  'fb1b89e24d8e20b91a44db4893ca8b48',
#  '63d7f9074ca7046a07470d5dc19eb01e',
#  'cfb55df57aa9989b15175f7b6a3925ae',
#  'c71bd8674c56fd9cc02447df07e9157d',
#  '2d89fb4861e924e8209ae3a55bd2ad2',
#  '3115be57096906cec38c8ca17127f0d3',
#  '44220b04d3803df4c94132c6b1fa1d94',
#  '1d0adc37cbf7323116b27acea3eb05df',
#  'df604265fdcaebf20b72397b9512910b',
#  '5a03428fe5887c6f35d5db2166b1812e',
#  '954c07d6240190c01f272f14eed93ba0',
#  '9f19cc76a77dad5754e1fa52e73a0476',
#  '2e288fe5104a35b0a38bec58f5e46487',
#  'e1d23e3be63e6d2eb6fe6201c8dfdd27',
#  '7d1e6a27b3ac2363458a550e6a5019d7',
#  '190ceac755b185e9b45d00897d043a1d',
#  '2f0f75e30cced53d817c9cd89b6c363a',
#  'e44cae9bb570fd3032ffd04b804594b',
#  '1f682a6a2ecb48365b8c93ec802c2bb1',
#  '713a2b883c9d955aa359b4472fd241f2',
#  'ec39cbc29cc50c3e89b87c4accdaee6e',
#  'e31e80a90d27ec54c8638dcf55220c7b',
#  '420b7cd72fd997d51933bce6f6b5cc9',
#  '76c2d12b9dc1a62d11567fd1b75dd01b',
#  'cd7dc20d5980a38981ac11d9a285eabe',
#  'a25ee33d1c507472e9c3ac929f3af64f',
#  '3ac49097ef43efb5a9dbe7ee08178c82',
#  'b9ec7b9eab1e8b6170b8e40441c7adf9',
#  '75b7c1647dc398e9829aa6d306ebafdd',
#  '23f2f8c0ffb65cda9a44e39c330f4723',
#  'a7ee84a32fd16f3ed0108066dc57c00b',
#  '40ae5a2f3dbe69e17b9c02782fac2b07',
#  '15d159d079dc861845fbd3d9cc8faa09',
#  'c7b24a16b3aceb52b74716154580f91c',
#  'f11bbcef8a65e816254289930ab1aca0',
#  '15a60862b8f681f892377404a2b5540b',
#  '1105e6be47909d137bdc7d70c965f694',
#  '3573095b298e2cac86afd687845b2ef2',
#  'c5e6a668c5224293be7fb1b1530196d5',
#  'f3235d670c2e72a9b2b7079a67e3dd53',
#  'a4d97dab53dbff6f4f0dde85e89ae6d4',
#  'c3e2eb797237e3b71ccbf14c6e1135c',
#  '45413712c6ccb7cb468ab944588f7c0e',
#  '58d8116604fe380ba23ce770c14ce438',
#  'a0b355cb8ec57e6fd9b168e0cbeceb50',
#  'de1c0cc45f1ccb33b3b0b7bdf1b0f649',
#  '7ab56f419910909c32cac08748a19cc9',
#  '4b9193d0074efc24dfcf943a8bdac522',
#  '66bef6d2bad630e8e6e62ad839513ba1',
#  'b51245f2d21a4371740455c75230a0ff',
#  '5e0208b31b51fd4a9365babfb2ccc668',
#  '5ffc9a86c384ca2dab56dfaef5ce7c18',
#  '751275e60ad47b84c9b76a4d2cb1d8e0',
#  '8b6d0d5e7c628721ca73a7c1434e9cff',
#  '9206a64b08891d30571a24de00a67b65',
#  '191827b5724e7b7646c39794b76dedc2',
#  'c86c6fd76a86cdf9a79cb5c5ae2edfb6',
#  'bf35ee517a3a8e85b27e24c8aae7851c',
#  'd2739d34b85078205e294c46ec69d51e',
#  '582e312158ec3fe30c8b4b75932a8e56',
#  '417a407b70e2ea03ef67a9d7e6fce5dc',
#  '4290e2cd95f860b0e832430c76ccdd7',
#  '7b486ced8408df382ac28ba4171c78fe',
#  '8456cce3cf7ff299ad06ad14a980feae',
#  'a53f7793088204982513f5a04f8c332a',
#  '9156de11a54ac699a51461785238077f',
#  '79997a0c029ec0f6020723c28c04d6ce',
#  '295a44b1285ecc7edf71108788dfd46e',
#  '3a4d8b3f4121efbf224dd94761f9cb3e',
#  'ecee72de8269cffbd6f84f3135f9b833',
#  '353d5cfb2391f4fc5e38dffb26fc6523',
#  'd50c9c0bfa7e9064d83d817073c38c4f',
#  'c85505edcade4b35e8381ad57d2fdcec',
#  '7b0ea81c0ccd9f769dbece2302c8ed6',
#  '4c4103fd4d5b1d93f88d4f535504a9fa',
#  '1a2c9552af496cafefee3f7fc3a48f0f',
#  '75d63cde9952179939e5faa334311398',
#  'a8b4f867cba800c2497ddf8d55a87ccb',
#  '1e0ae784b4fb36646ab9ae8b3430054f',
#  'f0978216f1d9c4191f935468533267c5',
#  'b3edcc4cebca730331831c8a169085fe',
#  '7cddd76000f57074f9e123bf0857e572',
#  'fde424cbbf9b565b07cc6edc1a8218c0',
#  'e80b30c9272ef4b77f376e790a8cddf9',
#  '3fab62c691e26431e5cc05884d89bce1',
#  '2d4879a8f7a5857aa0a3618b59c139af',
#  'b192d3e0196dac1d399b2b5b630fea88',
#  '30ef7e76b08d3299ec95895535065012',
#  '6849a77f5fe74e1e3338e30e2ff9bfcd',
#  'c4486107fff2dc76bf20b6578b3dcb78',
#  'b3bcdddaa35b898a6e5edda4e40e16ef',
#  '6e8539d0708221a2466837f11f63f21d',
#  'c374f1eb7317e5e32c3256e19f3568f6',
#  '56cf941f4fa6e1977dc630abe5b1d383',
#  '6e67efd4c435a3347d96c544f61fc4e8',
#  '1fb0fcaa964cdacbe65544bce7832ca0',
#  '6d4b360f19f67b5b15441b153a569bf8',
#  '24a6410e20677071660df502386f696a',
#  '70e0c525b0e8d7e122bdda452d853d78',
#  '20cca5017c6a64c12c48bf12f54c23f1',
#  'a72f35ee52c6748f5e85229837c0efbc',
#  '4d7e7f8778e603cba5ff60ee4451f5b1',
#  '281e6027627f0418a9ced8c64c538c7d',
#  '48045939edb2fc8f23b1b87bf80b4e25',
#  '885b6043104b5665e337da62cf31cc10',
#  '6bfcd2fb42bfa46d79a996cf9feaa8e7',
#  'd82a24ca80604373861104341f11809d',
#  'e8011ce59f04181d87d495c23681c93',
#  'f9040beeb6250f529818b7ccdb89c09e',
#  'f0a42828086795c0313be5438f53e3a5',
#  '3adb3467cc1186a29991600e74f35be9',
#  '8442a14d64aa6d152de3ee5c0b95208',
#  '1786069cb322ebe001a8ee64e531ad70',
#  '766b9eff25e8874696e5820d83447d32',
#  'da00eb2af2ad828150d12656633f840b',
#  '6167ad66305a8681bddc0507bcbc1393',
#  '10476fa092546c94baf0af18f2b9c846',
#  'd31fbe38964b0f2682b32f7f9951df5f',
#  'ac0001301d558558360a58f2759d66f4',
#  'cf582fac5be984fdde8e1bbc6c4d71e9',
#  '9824d98507587c1f839b066225c9018b',
#  'e8242fc80ff3abafd6613664b162518',
#  'ac5be35fa697ee0e5c867f379b52ad04',
#  '964ada03daebfee0ebdeaa9c1c900726',
#  '951ab06e6e700f67146c30d3f3418ed7',
#  '4c6a1ff51160647635b50a0c0654cb6',
#  'e45a24fb883fd73962a73d97d06eb7fe',
#  '9f9aaa0dcc2af4141dbec8646d2f334',
#  'd7df4e51c2f4ebafb9a7d4c9460a4e23',
#  'aa12159b835a2e45ad3a0a5136099a35',
#  '47515671583907f7772cda78e466f024',
#  '2a459be66a65e209a1c7085b478721ea',
#  'c11f4097c741877e8e67ef42757dd06e',
#  'bbfe418e1a19c4a3b70c488c82920abc',
#  '3be3448ed4790fde4d279711f72777ea',
#  'ed27af35080ada2f31f1cacf939f0b02',
#  '87674e527a2e640ac23f67d75d401df6',
#  'f720c33ac2f12aa3d6794c8dfc261f00',
#  'ffdf44f64bf3b0fedc7491aaf6bc2389',
#  'fe29d51b7c833156eb05911f805dd48c',
#  '92137d0af5fcedaca188aa9f4ec5307a',
#  '948a4f8c06084399a17edee3ac8eda06',
#  '21185c8bb90e3d28047c427df68f649',
#  '621f36dc0535ed2a68e966cc18fd2474',
#  'f176669e78abe3532b6879a840f82370',
#  '9746f9a6746416505bb7e3f0611337c6',
#  '1be5046e8d44a605e291671af0b40891',
#  'aa2c704cec467914f7f550c0717ec813',
#  'b60fc6c3a55676d3d98580f1cfac800f',
#  'e209b83ae3d2c4cd540da9e5b40c33b4',
#  '3b2926ece24d25b65b2e3a84a86ef499',
#  '6624e1e098531140839ff408ae5f375',
#  '74bf85b2db2bc0822a7998ba3e7a5f73',
#  '6844ffa763c6feff18dddd1cb725ed35',
#  '941e5ac381ed2ebead06c39aa5ae73c2',
#  '39dfcb7683e988a38f90684b72373572',
#  '6e21def4277bededa2b457a783e788e3',
#  '2cdbabe3a9554b8fe91455e2b55d8319',
#  'd28345eb574ecc92366d8d89304b1c49',
#  '2d559246b4ac233e6dfe09a8ac823a0c',
#  '987f667ab9cb45a552ee482c3040373f',
#  '8a30f236fda1655ea2b0605561429796',
#  'd6c92bdc316e8f6f87908fd254fb59bb',
#  '91e49fef931ddb4624e36a307a90527f',
#  'bf1e1f1cf03f03de8382e6eea6ee14fa',
#  '6371d83d0723a17339983730cf07f183',
#  '755f7be930a8b6069df563b686c036c5',
#  'e537830ee7114bb0c7595b28f3f720c6',
#  '737deb126fae83a9595de262bac86e9b',
#  '6aa8bf2d1c9049e65587b6648f4d13de',
#  'ddf861400a50c9b66bd9feddc6f50c93',
#  'f44e1ccf7908cd8ccbf10852551b617a',
#  'a3259b3f91ef9bc549b70ce009717bdc',
#  '8663babc52d7736bc4136e4340842dce',
#  'cff92756ca84b510e00985048952a12a',
#  'd6c8abf33a9fcd6b1506d6c5bc00210f',
#  'a2f040d799aab57aec17f2e9d98e70e1',
#  'd01ca8d314ebab516829256fb2bc508a',
#  '4177621e11837754a48a4b55de41956a',
#  '2f957f0dd920b4f6ea29cb4919fd79be',
#  'be8d2f470428883e6fc22fc9f76585ec',
#  '55082d66970064e320cf7a3434afa0f6',
#  '2eb3e78f9b3cb302bf95936ef305cf78',
#  '5c0ac3f6a32f949d3447f46f5cbf626d',
#  '247ae150c20fef3c7d7f2a8c3a3cb528',
#  '93c8d73f3b81863096aa9a37bb89dc6f',
#  'd68886443e4713d4826e2bd734031944',
#  '6356cfb98d78d992eb262c2d2d21a7b6',
#  '16e3c0982ff12dc56f8224a1a2b3259d',
#  '4549a332ede01ca54c29a4725d01d2d3',
#  'cf50569c481bc45a4c551e36ee28bb8c',
#  'f247a77778b9d37b6b234838ed7aa49a',
#  '40345e65a2927a9f2cf9f06b1f34422',
#  '12749b5967ac61239c298bc1217b76f9',
#  'b09f5b080e1252615d2d7af9eb5eb6b4',
#  '63d56925628fed190048d91396f5d4b8',
#  '4064f6d31e907ad96ec9f5d11d62fe03',
#  '319f62d570339c89cb6e51178e36118a',
#  '5e65fde0536825d8d8177fac875755e8',
#  'd863001c99e50c4ec1380e1f07afdcc8',
#  'ea19058bc3d6226d40197ea0a279579f',
#  'e35e1168b6b6074d9d28eb00e4e8e0e',
#  'a1c37df601df86ad41aaefc704922955',
#  '637c83f5fea449780db909a4fc2ba5f0',
#  '101b7e91c65fffeb87282ca0308af455',
#  'f6ee2cb0de8d6dcb836ff857eeef78bc',
#  '97a2f58749d1d75ab9362a015f1457b4',
#  'a1a77fb3aacc16b197d8cf86c79533e',
#  '5efad85507bde1d528f1a8b0a1ddd23e',
#  '1b6c63526bd9210a806d5bf55bec7ace',
#  '52b8f39c8ca7437be7caef091a8095e',
#  'dc9f6b328c1512d788ee4aa64b35fd01',
#  '18b798e318749023964280c0eee65978',
#  '188ea141c0435e19cbf7b1f022627f80',
#  'df307598d566c5654722abbfeaa0316a',
#  'd644c27525807fa8e890af3d8e9b220d',
#  'a26e67fafff492969570e28ee9b5851c',
#  '5c64252a3ed131161dadb45819f91a20',
#  '7efbfea7edcaaf6c2ed679c7476ac46',
#  '1166cb7ce354172ff498f285de2be214',
#  '89b7d10c813bacc5d27ea5f7415cca44',
#  'e1ea52de0d658b79361c17eb2f89c2ad',
#  '34f31854286f1d2ca53013895cf4c56f',
#  'e6bed8c1433d22a6c21f9a792d80e8af',
#  '79e9e4cc8a40d7ed389fbd41663fd5e2',
#  '151612a44330119f1fe5878193300825',
#  '3355b6b4ec212119d1fb5e30ea5e0c3d',
#  '206881bcdfaf06843a1622f5a3af7075',
#  'd6c7d130e26aac0c7fbddc765f77608',
#  '4a2d62aa1730f6c36e6e6cc051ef74b2',
#  '6e74391a5d8cee607c33ceace217c11',
#  'e410a877c8c1c9faf8f988c72b1df29d',
#  'c930e7e4c356b9d4f5a56b71983df0be',
#  '17b61e917263f36f0961c84e25f70493',
#  'f75b7c56d8087d96864b9c3d3b42fd17',
#  'bfd8c07edf8d718b56ffbd3ffbc256dd',
#  'ac8437701a8f1130ff4b2356244035e6',
#  'a591e6b25493114e4710870334d62d72',
#  '65fa090b2ad21555904e67bbf3cfc9ae',
#  '332e7687eb1f84cde7bdad26e480871e',
#  '1e8c0bbe802739c9bb2614cf01ce281d',
#  '26cea37e545d04928fc796e82bdb8f8e',
#  '4b2f69233243191fb2d59fa6f64c1e2c',
#  'dbadce2120d0c2bb0f8c6fae0189be4f',
#  '96e2ef23907ad270ea432026d980ae90',
#  'eca5d25a2d8446135a28676111a2338b',
#  '3e2007997b0ba6c214d0dc600fd42b5c',
#  '905e5357dc7d1dfa5fdd53642c0c7f3c',
#  '1abac92163c7c4a410dad56c8feb7f18',
#  'ca2b6f36777779637fc6784ecd4d262c',
#  'fadac233cad6ac9e81f5346e7770e4d8',
#  'f143e7453af9a8363169841ef0f2d842',
#  'b9c7f28d53684939083e36b756fe5035',
#  'e3492a2d064536ea4f323a25beefc791',
#  'a2d68de03cba2dd190f93f4ed82dabac',
#  '5a24fa4f88e4499e6dcbca23a911788e',
#  '78b7fd1ae213865daccfcf775e082c6',
#  'ec4d6e472a675124277648ed481f35e7',
#  '12aae6c60722f5f8b20beff157cea352',
#  'cf87e6501439413635592433c0427177',
#  '886ee0cac2d4bbd91509e8d3ced29440',
#  '77a22bb0700ff393615b6e34156b5877',
#  'c1480006242f022a4c84a53549eb3546',
#  '8b5ef4be0c31e6fc91ddfcb13b6f35e4',
#  '809170ab021a500d133a8f3ffde8814',
#  'ba33296f67d8442d04a2f32cf6b6bdee',
#  '824e0e38f906a332769d64f893839597',
#  '6a1396116d91673b2139233137736fe2',
#  '898de524a83d2bc62a181aa8863a63b1',
#  'a24266d38ebda5099f69b24065559e57',
#  '558c446958fe74004a525e036a4ba5c1',
#  '4c54b7c0eddfa3cea4e6794fb63fbf51',
#  '103c43bf5a2b2bcafa37c5743c752a77',
#  '7349e7d9b8c6e98f7fd2e4525c19d62c',
#  '439a319ad6c27d3e935390ab85350016',
#  'e58b683b6b5d140458f30f4008ead3f2',
#  '2e0cb9e02577ddb15c0bff8b2ba0b101',
#  '64bd275d624a29bb330ee92c6ffeb0e2',
#  '9b656dc478843e7cce280a8b3a2779ac',
#  '6790ee072ad39dfebf38e7a20ed54074',
#  '76c947f56ec6262d5ba66e11be4f6829',
#  'd69ae65bafc7f7dc8299b3c93416756',
#  'c1bf469822d964471ef82a799784ba37',
#  '3734199bc3a38d83e55ae181e43a949a',
#  'f4915a433e8b4ed38216bbc95fe1db34',
#  'db5442eda5c21aefe038f4c819711f6d',
#  'f749608e435fdfeb64a8b9ede7c3b6f0',
#  'bb30941d7366f184059c3e85fbf23825',
#  'b60a617ee9e72627de991e93303a8297',
#  'e6e594d05f7a135e4bafd608d2e46d98',
#  'a96fcfa691b71fcaa057033bea8442c0',
#  'df6138aad276f420d8b1ebf829015152',
#  '814795cd10155f4ae40a4aabf3adeec1',
#  '5ae16fdf704dea133b67656c971d997d',
#  '406bffea78f93ffcacb53f853d7d6773',
#  'b8528a4f489fded49709a7bb94d8e25f',
#  '2cb9fcdbcb8794a229c70ef4afdf5de',
#  '9ee6d8179c14b6f8a31c843088e67b89',
#  '805f21233a1d888e9cabcfaa5900b80',
#  'bc5de7b1e2f4c00b47f48d10fe080a5f',
#  '1b8ebbab6ebe891a66c18e3965bf3fb9',
#  '7d99d3dee14efb5e0bbb42b8a5077d54',
#  'eb4e73e763469da9e9e903a7b96639c1',
#  '707d593a070927605a8aa6beeb2f8b9e',
#  '99e80fbe2db23740b8709fe463a045b3',
#  '416381920ee3065d105bdcffa7880531',
#  'acfe732b97a3e54c2a33b09e8cb4139c',
#  'd8d72f12724609fe247c6d212cdd10b0',
#  'bcb9bb81b8e082299383fa7ac7970744',
#  'b8e7c37e715fb0e89d736fbcb1d5d6b',
#  '89a1c93d3bafa59aea2c6db44b9ea575',
#  'c29e4480845dd59c1d5e781fc8c7908e',
#  'b3da9ff3b369bff568177f9a5b738dac',
#  'feb2370e38d0be8c013d7e4e403cdf39',
#  '36171bdebd1363111c37bab6817a527a',
#  '4c6ccf88ab894f96d525c324fe6cfdf5',
#  '66e7de3df6429b2b513b6dda43860830',
#  '73454c28c355302569d072c30f4ebe30',
#  'a49e8826d09294b0d682df9384f6a151',
#  'f180c6c1d4a11b4df97610f88ba856ef',
#  '53ac2bba79223febf00b2158250f5d68',
#  'ee64ae690def7355856f51cc714782e',
#  '26ad015fc711aba719ba41dbdac71d7a',
#  'c26253914fb0c6dbcabdf8a763a571dc',
#  '940d7ef21ffe4ac47a533189f97d2820',
#  '58652c3a8192ed40209c74bb2b0e6b06',
#  '87f61c80a031b0ead4442e0aec511594',
#  '1374f4159cc601b722d651d0e54dfc15',
#  '5c8f6a413970ec69f57c5fb53fa7b75e',
#  'a1971eb4745ef2656b016da9e2df5144',
#  '4c9f21b195f9cab0dbacc58eeecd001a',
#  '8bbe327c281d763da38076d347cb73',
#  '6dcaf2fa5528a45b4ecc2d4e26cf396a',
#  '30b34d2db3c061a641761b66177b3cda',
#  '122bf9a294f77ff6f84929ce8120adfd',
#  '8a80b43d2d4bb4d1f5feb38e8928089a',
#  'f41d10a00df416bc5521cc935f12c338',
#  '2ca0481047f5c5ecf711ed5448059344',
#  '2ffb837ae4cfd20c46dbc4e6616d7d5c',
#  'b494b98d91251d90d7ec8ac078a68e2a',
#  'c343d508c2f2d24393037c6d7c85ef8a',
#  'e7558a7eb6387220ee46840164bdb98f',
#  'ef251711257e016bfd84caf8311937c8',
#  '7d7d4ef179ee7002f6ba7ca99488a774',
#  '6fae4e928edd3cf2f3d7fb6973cd09b4',
#  'effa86d854c4824b40e323832213749c',
#  '51b393556ff8cc0b4b28ae34ff30c6eb',
#  'a5f62acf97bd036248e7b0c55267fc16',
#  '36aac475f4221733f4eb77961b40d061',
#  'a34cd891ad01fe42a3c9fa8b855f279b',
#  'afcaacdb8ea2e88d8d65452b60ff431',
#  '3679c4c75a218cb3e0e571e88454e6c2',
#  '780a6c12e840b6ba0f19a5ff33236bf4',
#  '86b846f8de9f95a95c96afdf9b8ba371',
#  '12a4d7e9e9aa0ec6a3e5bc33c9a470cd',
#  '9f448a6370817a3acc46cc2e8ff8277e',
#  '3725610522e019147ab2b5f3d01a87f8',
#  '934f7704d0845199c78433923c972ff9',
#  '13f7eb5594e503d1401065e8c7e0f267',
#  'f934e454c2636c28493c07e3aa1ecd33',
#  '75a2b94d8e67a7378986ca9d57017a05',
#  '72d5790820e0c473f0b8e115b75e674a',
#  '97a6b1e6480f433a60a4807dfe58494',
#  'b46d17fa037d66f4d75f260444a160f2',
#  'c0ceb46c8af08c5157eb19cbc543f490',
#  'b9c594a0e494e3a91d1a334b63117f30',
#  '9b511335e9f1081c3b4f4dcd941cddce',
#  '11ae5c08a8d373b42e6b2418e4dfb9e',
#  '489f4fc0ad2e381969a2ada3da393e56',
#  'd55eb9f1a44447c646a68e44a90992b8',
#  '937377db6e42c32ba11fc263030b519c',
#  '72de338667010881b1999e89ef5e4d89',
#  '781f8646251a717db638e3c39160e147',
#  '3799fdad301dae8b2952cde9881a0dbf',
#  'b0c6aedf4b5dddebaa7b1380dbb44cbd',
#  'b79a0d68424824f8072a50103f928af2',
#  'f20c8cee411809f645c311389e2f153b',
#  '5091e0b4cd7f07a1ddcad31a6992159f',
#  'e62c2603c6253742ebaedc4eda9dbb9b',
#  '489c96c091bff6308a80e82a85766cd9',
#  '3f37071497746042afa997626b6202d3',
#  'b3234b384ed12a9d2e703b2f0b746a79',
#  'f07388d497f814ad0a1d926630c0b1ac',
#  '21729ddc7919ebef6765c40bc1f46897',
#  'c1ad7c893e69e1b897ea08a02544133a',
#  '20296a6c7d703c02e62251e22fc61bdb',
#  'ef7de8428d13dcee4f0b786833f1af3d',
#  '6c1bbff0abef496fcb26c465c96d73c1',
#  '8dbff5ae38c2fa195cd714f6816d81d7',
#  'c2499c6174b3ebf8217ba6e2252b5066',
#  '2a474af993c3cd595b60f9de85498792',
#  '2d365f340af1d28e374c66fdb8841f0c',
#  '292a1305db82944ec3db4d0d50965aaf',
#  '6703ad79e1aaca497be15c347c1efec1',
#  'd7c4da952ce811cad77e422efd6cef21',
#  '4e28f43ad59cf5681e02f6328b334820',
#  'caf20e39cee5a8a9d8e7e9d54051ac21',
#  '5e092e4e9d5abca6380f0f0be93a36c1',
#  'df60aec708d866496fc3285f75be9daf',
#  'c6b2bcc9f33b995edef94996065058cd',
#  'f6da407fad405c78be2f5797aaacc1e8',
#  'c217ab82c565595eec86437aad54c2a',
#  'e84675f06786f3b6cbdeb58dc8274ad5',
#  'ff2475f24861f701183b579b12187927',
#  '63636d65af848994902d978ebccb85bb',
#  '918de196f4244050c1456958b0ff10bf',
#  '9475afb57fbd837e871722830cde7ee6',
#  '865158c355fcffaaeb37bdc15308a22',
#  '94b820618fd3e05791e9b34ed8765a31',
#  '3be7b2225bd0171d7f8714cc0bf75d06',
#  '7a8112a96ce904906e27a36c37413b00',
#  '9616ecddb159ad7ad99421903ac05499',
#  'f147bfb6c5ee5b74ae53d8c40649062f',
#  'f4d53dfc4b1dbab39a65fbdfe7233bb',
#  'd4ceabfd6d5966f90d9f8ffb9dad2f38',
#  '89f6c14b84ca2af6f9b01a2995d68229',
#  'e85d4cfb8438457d289bad127f6044ba',
#  'a7dbbcc4ab7aca9f69f06d2babd71109',
#  'ea9d38c7c8725e412347b41c7b9d9e2c',
#  '747f740d4f3b806ef95b57ca14a3a3ee',
#  'e3251297fec8d7db0cde79b6d242467a',
#  '1944b9e994bb68de6295c8922dbf121',
#  'b26afdd8a081322e0ea2672874a5f629',
#  'd4d450a6f5bb296067c0cc66bd9294d5',
#  'a4a08f2c8d6c5b0b32acc8ce77a702f1',
#  'c57aa68aaef58dc9dcdc8ab109232845',
#  '5685e660b9934e00a0a8f66d77549d02',
#  '3cf4d519538b605a36b99c46f6d09eeb',
#  '835e56daddbc0cf0e6babdd891f51358',
#  '23b5b6b3476f274457e800f3649ddcad',
#  'd7e53da857f12df08a763ae61062a65e',
#  '37b77ddd96fd9d7a10207656634afece',
#  'c23f0c996a75317e336c7fe56d04af6c',
#  '53f06013bc1958220ad06eeee6a91fa1',
#  'b0f9e1d5d5ec4f9aad18934b378d2933',
#  'd23ba0726b69b44d87c69972bc4fb4a8',
#  'af3c3f7fcae5bafc49d2bffcd200ca61',
#  'ffd1a043fe3a084a71685e832350c12c',
#  '11f49c7fb55b226c061c780ff9e58204',
#  '5f3d0c26ca79269410645cf67507c3d4',
#  '2f8521ddcda30fbe4f4f021157df9dd2',
#  'eeab3eaeade14c8303396b9908a4b8a8',
#  'bc7f0009cdaafc1487ac989fbccbe60f',
#  'ed4414352a72519a7e6ad8ac6bd489c0',
#  '67d1117648b2809d8408e04399e7ac7a',
#  '72ae11e387a78465e00336c24df9bdf5',
#  'a1f96f5c2a02fb92cde6fe45e862d92',
#  'bf708ebe549caed91ba6f5316584534c',
#  '39c7ae002d24f42bcdaab8a79800bfe6',
#  'ca6f1968dd57e43ff5b45e9b580b05d4',
#  '74a2b0a7318c179a40ca576b274e952b',
#  'd67c88bf5850268786245ee21c2dce3c',
#  'dfc65a8840bf63d3fcff6c40ee817a32',
#  '95a6eedc4122a1ada6622884a9048140',
#  '6380b652f4941c4368ab5ff24757c29b',
#  '13d4e85c8853b9b1a70588ff09356dac',
#  'c7cdf27ffd7cbf3b0e8205587e2c621d',
#  'b15c4c668bf35822e65a861b52f7ebb',
#  'dd8c900db94c451002a94ae37f8d9e6d',
#  '440aeb91cbd921c9d84fcf5a7a7cfcd4',
#  '4e6f01c6803fb967f167bf8bb1e829a4',
#  'beaf3c1fd0b1dc1691c3e0a557f15b39',
#  'ddd6f20ccf5c6e599295cbef880ec328',
#  '21823526c3dc80a4e41ced23e08a13b2',
#  'af358c806dac004696fdfbab5a4f9a3c',
#  'b67fbb03578006e1ba367581a979f010',
#  '888fb276582537e6cbb354a4925bbbbf',
#  '6fe814f0c23e2e7ff522b048e60d373f',
#  '1b08948956102230a50165aeaad47a91',
#  '5b8f3b775146c8741fadb12c17ed9290',
#  '54379b2e01bbd59b034a603dddf76381',
#  '3d01fdc0bc9e5599a7478a49efe7da31',
#  '8819cd5c59a0cba79591c91611b25f46',
#  '3ded63899352e96a000ae4dc2d22d1a4',
#  'c00f0087e48301f8f85008532a82afde',
#  '761da7c8cf1929d45298f5b5c2ed2d79',
#  'a7d9948a30934b51a48b9eeef486468d',
#  '98b07869ff09a7c2256531748cea2fb9',
#  'c97742df2d1b13a0f3dcc4e3fd856247',
#  '687148946f82b71ac7853c4266c52498',
#  'ed6628809de24452190b6667262f58bc',
#  '73244b62b6f1ab889fe7e2383ba7d85a',
#  '57a1c56c301180fc9bc384688efc287b',
#  'c64c63bac555e2a76e1858523958913f',
#  '62099137aefecdd8917caa69a7dde708',
#  'd92017939a8674a84ddc89d45fa29ccd',
#  'c681837036ad368c84ee4ff521c98a48',
#  '8b8d533200780b92245622433a09528e',
#  '5c86268fcf77ba4f5a293c2db4fe1aa5',
#  '9689258dae5ad27fcfc00c1bc1fb781b',
#  '1edcd3a1a053e349095eff0f4527f7ac',
#  '46de96c7e9eca64f4de2589f0874197d',
#  '6090dc7931ab543bdda9defabcdcd178',
#  '52028de8cb9bc6e7ee67490c96980a1c',
#  '32ea21d140f85beadddf1097cb65d1c2',
#  '4c98faaf2ed6990b6fb8d9159fb2c45f',
#  '34fa1d9f0d283f6e5f0d84c88dab239f',
#  'a63fc44b26563678158a407dc4c39b81',
#  'd1221c758bd08f3109e1f3767c7c771c',
#  'd32216779218925819f324b4dfc69e5b',
#  '8a00e781bd3b99eada105522ae06a390',
#  'b8401dd7f6d60055f4310a0233bbba94',
#  '32a213cd49cb40323c899d341cc1c3ce',
#  '886ab2081611c8e86320f20eab94fa54',
#  '1b9900ffcb9a297b9cfe7c7ea0de710a',
#  '9d028818dccb011464877509c58686a2',
#  'b909693662c702f8d0cc4c57a1b31cbb',
#  '2f6ef3c7647e6409f3298ec89e0236b3',
#  'a2e20c65e3d6c8aa4769105cb0675e4',
#  'de5c5734d56acc5da30f086f95646805',
#  '90f4d08dec95be74c70b0d49b2c5e50e',
#  '38a7ae3f145017c17c037d132b9e9141',
#  'e2826dcff29b973d9259e93bcab7e5bc',
#  'e899aa17f23560da7e86663217a8e301',
#  '2c4aa9ed2134bcdb38877eac43919801',
#  '51b4eae980ee84fdf3db4a5fc3858dfa',
#  '4ed789282e7d4ddb8272e27fdc0aaa59',
#  'bedd1581d93bf6c1347d10ea40bcbde0',
#  '2fec859e759f4e4d08de78e53e8a20d6',
#  'd1cd7a25ceb086108468ce849ebf7f22',
#  '3fd8c428cd2806cc34b075b6544a5059',
#  '503460328b944c89e5a4b3262f99e195',
#  '146322614f93500f5e850ee35c4d5fb4',
#  'd4efb4f4fdddbae686d1a11ae6dad6b9',
#  '79a4ab25f7716a0eff868c7232597df9',
#  '5e82073dfd2648a795bd6c6172f42e87',
#  '647f3238b2add5f775462b11c45b4496',
#  '84e87d322da75830bafa16efd0a97114',
#  '19957e4e46160c4890e6a5b2bb6ad197',
#  '816bd67ba7fd7bc6a4536fe7816b295a',
#  'edbdf75a9052962b88d981d6516747f5',
#  '1616087d98c21692bfb9c086a22e5ca1',
#  '1a28f30b53f1d8c27055c8b76d7371fc',
#  '184e2d3ef4ad488ea4c51240203023da',
#  'f0d834dccea6df79b56ddf23a8018bf9',
#  '878d5c1b6f1d81c0fffa5144b3cd5f6',
#  '997790a61d0015080c31bdcc2696cf34',
#  'aca941d0b5ca9d1533dc78812a97a687',
#  '63e0829575cfa6aa5b632390537c7931',
#  'ae1097c243cea8253ea6dee522d474e',
#  'd1b1a996badcb64221771c2b3f55b5bb',
#  '1d82672efef3f5c7a911355e55fdd1d2',
#  '3a4e5242521925af972fcebf71e5a8d6',
#  '4a743fc7ced4fe1331f62b5e2febcbe6',
#  '345fbc3e5d8cade852378b97bb94bb4e',
#  '890605d1a92c5ff29328f05a1423e305',
#  '125c4be26c7ba472e8c1b6eb288fcbb9',
#  '67d147cb9b8ac79dff5239bfc6eaefb5',
#  '17935a80425ed4f4c7eb24592d6dffc1',
#  'f3a5921782a412ffc89a95e73515f5a7',
#  '9da9357640e6c894cdf6e2210d6c6de3',
#  'ce6312eb34edfbcae3b0a9393f29df87',
#  '45018fe2905363be5ce246da91b106b5',
#  '729739f6f1a6874f93757b6e1bbee5c3',
#  '2df9cf927e24aae70dae6d0f4203c4e5',
#  'd8df2828180b9ffffc6448b3e37350fc',
#  '13006901a4a040182accf64680c17bd2',
#  'e29d48d304b8f8d76ad9c5a1398b237a',
#  '4af47f1385bc16eb1afe6db3d579c593',
#  'f865bd13c5880ec360905b75993ae9b8',
#  '5bcae04014dc72fdb2d0e552cb51d1a2',
#  'e7a4cbb3739e44d39909b0ad2d8612ba',
#  'c7c7053d7c2928fa30128658a8724a94',
#  '26c2fff17a6d5bf1bf9cd7f5acbe2199',
#  'a185c2c50848ad39e758c93578c94de8',
#  '6b0f27729ccd72f4631eaa61a444a470',
#  '5745e35a6be876e500b8d96f907c6fdb',
#  'd766f520f2087c7e295929978706b9c3',
#  'c7db1805d0f54ac39c8d8a01300b80f4',
#  '760c3e39a7191a89d3b4fe1176aa7bd1',
#  'ada9c0f740124c2212090f0e223e3ea4',
#  '7077ef54b51f88908b5f55100951c099',
#  'e5552ba7b152620200ff4295b9454ff2',
#  'f0978174e63a70fcb9fcf49a84ff38d9',
#  '508f7f21356e5a33fc4a4126f51c69f2',
#  'ad1ce518a84a224beef560b7a6a4ba2',
#  '717809505576d94b1a02055fc3043bc9',
#  'e78c36c09a34afb7b242d3d3885e354e',
#  'fb84b110da48b4f777153a8efaa3f654',
#  'e373eaeade9f45eca2114a9aadbbbc1e',
#  '343f0c0ca5358c4359fa98a454d66d41',
#  'bd704d0082d31fbb50b4754f3596d1a3',
#  '2ce88bdae53ef37851f2ebcd1248fe69',
#  'c74b3e2e72dc08aee7d873a7dc79d705',
#  '20e8415ed896dbe46234cbbcb0b537bb',
#  '7aed3458a4c704a626f6a0e3b5ad0f1f',
#  '3c8200611b23ee721378487233de4d25',
#  '3149593990c00f1690706e948437ab05',
#  '483ab9065540b0bcc9ecd7099793b28c',
#  '212464b99cefca641802f6551c4d7909',
#  '47f0eb59e275c7e46e63ac1d1885c9ee',
#  'cc574f8c23c6f6130cb77d864620be72',
#  'c4b0b8abe462e1d6cad89d298c3d2293',
#  '1b95e706f347094d97afe51e6db0a393',
#  'cb8c2cc983a490450c88028e3a6a2ce3',
#  '298c0a0369ac33c2798dcceea48673da',
#  '9f06ad5822b00c932c615dc86ce0b33e',
#  'eb20a314b41112d2504e43dff58c7a12',
#  '3e5218d93b985d537ce570049c9c3737',
#  'eb8480f531c6a24f31b3dc7063893909',
#  '88e20b33c3d7aced5f361ca59747837c',
#  '10ccd1aba6cf6b7fcbae3f8379ad48d2',
#  'f99747650c04608926357268f13f612d',
#  '23ad3c6c1a6c72e620d409d9ad43c253',
#  '3858228ea795ebc9a69878bd65f866ca',
#  'd4f87d55ca704d92002893dd94aa9c6c',
#  '110820d93484ab36f421c49711093bd3',
#  'c4f25974eb33ea1d268f3153c716a4f1',
#  'cc70592c45ba77b7e3471136fe522e8f',
#  '56d2f1567a9658b4d91f456f44fb2f85',
#  '886dc3027698d24479a5678207266238',
#  '1439a7517eaa5c9d31cd38cf2d9fc6d7',
#  '127ddd84b2bff4b689f317fd772d9ae3',
#  '6c042c2f7c213361744b4d7a15ed4bc1',
#  '8a7c9ad1b519ef2f43763a57af2e21b4',
#  '1cfa6a1134fcc629b79959dac9168a02',
#  '8b0a173570b0ab0371484a228ff097e2',
#  '87cad41c925dbbbfeaa3e71be306097f',
#  'e2c4e80645e9852ee0cb7cc673de85f6',
#  '5501950069c12de90b16798e198ce75f',
#  'eda715ca005018eea898852a9d02068f',
#  '6304737c220e9b6ac190cb711acf3e36',
#  'd214e1d4ac804390cd5af9d48f4f2aa4',
#  '7ca8bb1391a64c62bb7417d21c7f9aef',
#  'faa3d6bef4d976ba266f11e9dc47774e',
#  'ac343dc398532028f7806a1b32e5c302',
#  '8dcd4071f831adf1b04aa9f99129204b',
#  'df41f51667a619270260a5f214f4f2c4',
#  'd60351f7a20613e8eb8f46a5e194c7f3',
#  'b9c4374908bc1866a415c50639ed4b4',
#  '70582079f3bd2e1a98605d0a9896eccd',
#  '1ea0bfdf2ab674809f8454df5f36f3c9',
#  '3b0b4162b31a8b480f76f30c88459704',
#  '4e790b5b4e618070ab56ad9d73758136',
#  '46a59def90543541d410bd4448959e21',
#  '994661c8f2169574d8116e5758516cb',
#  '7eab410e10a88137eca27bc4df6d2e3c',
#  'c95ed3eee801a96358a48ef04b12488e',
#  '7ab48affff48736b9a8016ba72a50ab7',
#  '53768ffb93ee6b60f42421925c726f56',
#  'c479f1a44c0eff16b324172be5640644',
#  '330b68a9a77f99fed62c0171d3474fa3',
#  'c217d6d6342dafdfcd91daeb55703163',
#  '407c1985523a32b063358b49b19f6c96',
#  '8899ee460939c584f6abd943da454622',
#  'e1d52283f05f1b4be19fed42a5b653f1',
#  '4a60fa56a8c2408d755f19f89cf646a9',
#  'dd9494d1bff7fa477cc03fea5294a510',
#  'b42c2a28030f9f0d9fa2533bdf1e88f9',
#  'e23e82f21e258fbb6cca64a8e277d43e',
#  'bb72b8a211971ae7e08dd7c28b4da82a',
#  'df031c7c6a89f2f5f4e36dfd6fe1d5a5',
#  'c9a9421541a460193d0c3d1f5dee6f42',
#  'a2b6a49ac1e29a2617fd43016be2e617',
#  '1aa049b4f9db0d63fbbe0b566493319f',
#  'cadeaa304daa4daa9da3dab207c27a7a',
#  '9ea417426dc295cee72681dc58b1b49c',
#  '5cae0202780b02d93a50911d02987855',
#  'bb20eebecf0e9a2a3c6576c16356194d',
#  'ad2ddb290ecc123bc1d989491d9da02c',
#  'c24f69a9a5619058f33f87ff27cda370',
#  '2343571aaa574a47178e3faa7a749a8f',
#  'bbc129cd002c690ceb61ed2246f35f6d',
#  '67e76fcfd654fe946d9771e322d7819f',
#  'f1a89d8faa371e2c4014896e069b4983',
#  'bc81b51abbe7857fc9357e6392b8f21f',
#  '1447124186df3bad7eca2bfff8274f3a',
#  '9f9208fd8a03e9a8dc1dcde512eec2f5',
#  'f2ada911ccaef91bb936cd07b5ac7874',
#  '178643f410039312e0e66eee7be7ee37',
#  'b882414794b33f6c130aea2e88cbd627',
#  'a9bae0ba2b2e3ed16c4c0fab506d938d',
#  'f86a100514c18d33cc9e4e7aef7ce299',
#  'b45083465d47dfab479e624d640b91ab',
#  'faf900af6a87d66e972dccebd402b87f',
#  'f777bff48a72d3cde038b5398885536c',
#  '2504cd1154a05982e035ad4d198d69ab',
#  '4d6c05331c558d759dea14f40c31ee4e',
#  'd63b6f387e37dbb787279191325cc1c3',
#  '70f9b87db33ea24e98599de948da10d2',
#  '4e51ed9ecf7fa3420077cbc0ed18da59',
#  '1c6905012cec71097bcccecdbdbe3517',
#  '68b466873e4201ea4e6769de1d9912d1',
#  'a69c4a65e4e2b4c620bcecd7cf2d232b',
#  '4b76626590a8336dd604f1f165fe98bb',
#  '6a5eba7b6f2545f2ff78ce5507586911',
#  'e7c58f15eceacfcf54e108cbff20c9c0',
#  '46b0aa73397143e8586c33aaa2aa8c3b',
#  '535dbfd49f7df4a4995962bf4f7ba424',
#  'e7690f8914d591ce707680319b4f60df',
#  'c144dd419199f650b7b2c754805e0245',
#  '6ee59d31c32fa8134234c8c2df790aec',
#  'b6322e65cb445aefefbf8ec45acfa913',
#  'd6aa9613201fafa1cd2a9a768d4334d0',
#  '3ff6560693e0429be1fef73a72fc3e97',
#  '2845c51f08135ee7f7ace1ec06990bb7',
#  '9fffba31ea05d20e24ffbe402743438c',
#  '7c37d1a5ad83bc2886f9b3a70fc8a5ec',
#  '1400ec7f5138a595ccee78fe97b5a4fe',
#  ...]

# %%
# GET TWEETS -----------------------------------------------------

baseTrain.get_all_data(_TWEET_BATCH_SIZE_, tokenizer, _MAX_SEQ_LEN_, _PREPROCESS_TEXT_, NLI=True, label_hyp=label_hyp, nli_label2id=nli_label2id)
# Out:
# Reading data...
#     Done
# Preprocessing text...
#     Done
# Tokenizing...
#     Done
# Merging data...
#     Done
#
# Total Instances: 120000

# %% [markdown]
# ## Training and Testing

# %%
from tools.DataLoaders import DatasetPANnli

baseTest.get_all_data(_TWEET_BATCH_SIZE_, tokenizer, _MAX_SEQ_LEN_, _PREPROCESS_TEXT_, NLI=True, label_hyp=label_hyp, nli_label2id=nli_label2id)

Test = DatasetPANnli(baseTest)
# Out:
# Reading data...
#     Done
# Preprocessing text...
#     Done
# Tokenizing...
#     Done
# Merging data...
#     Done
#
# Total Instances: 72000

# %%
from transformers import TrainingArguments

samples = 4 * _NUM_AUTHORS_ * int(100 / _TWEET_BATCH_SIZE_)
_LOGGING_STEPS_ = int(samples / _BATCH_SIZE_)

training_args = TrainingArguments(
    learning_rate               = _LEARNING_RATE_,
    num_train_epochs            = _EPOCHS_,
    per_device_train_batch_size = _BATCH_SIZE_,
    per_device_eval_batch_size  = 200,
    logging_steps               = _LOGGING_STEPS_,
    output_dir                  = _OUTPUT_DIR_,
    save_total_limit            = 5,
    overwrite_output_dir        = True,
    remove_unused_columns       = False,
)

# %%
from transformers import AutoAdapterModel, AutoModelForSequenceClassification
from tools.DataLoaders import DatasetCrossValnli
from transformers import AdapterTrainer
from tools.Testing import compute_author_predictions_nli, compute_author_predictions_nli_LR
from sklearn.metrics import f1_score, classification_report
import pickle


# train

task = label_name

f1s_soft = []
f1s_hard = []

f1s_soft_LR = []
f1s_hard_LR = []

for split in range( _K_FOLD_CV_ ):
    
    # loaders for current split ------------------------------------------
    
    authors_train, authors_val = crossVal_splits[split]
    
    Train = DatasetCrossValnli(baseTrain, authors_train)
    Val   = DatasetCrossValnli(baseTrain, authors_val)
    
    
    # initialize model ---------------------------------------------------
    

    static_head_model = AutoModelForSequenceClassification.from_pretrained(_PRETRAINED_LM_)
    static_head_model.add_adapter(task, config = _ADAPTER_CONFIG_) 
    static_head_model.save_adapter('aux_adapter_'+_PRED_DIR_, task)

    model = AutoAdapterModel.from_pretrained(_PRETRAINED_LM_)
    model.load_adapter('aux_adapter_'+_PRED_DIR_, load_as=task)
    #model.load_adapter('pretrained_adapter_NLI', load_as=task)

    model.set_active_adapters(task)
    model.train_adapter(task)


    # create trainer and train -------------------------------------------

    trainer = AdapterTrainer(
        model           = model,
        args            = training_args,
        train_dataset   = Train,
    )
    trainer.args._n_gpu = _NO_GPUS_

    trainer.train()
    
    
    # get predictions ----------------------------------------------------
    
    
    ignore_keys = None
    if is_encoder_decoder:
        ignore_keys = ['encoder_last_hidden_state']

    results            = trainer.predict(Test , ignore_keys = ignore_keys)
    author_predictions = compute_author_predictions_nli(baseTest, results.predictions, task, len(class_dict), nli_label2id)

    # report metrics 

    report = {'soft': classification_report(author_predictions['true'], author_predictions['pred_soft'], digits=4), 
               'hard': classification_report(author_predictions['true'], author_predictions['pred_hard'], digits=4)}

    f1s_soft.append( f1_score(author_predictions['true'], author_predictions['pred_soft'], average = 'macro') )
    f1s_hard.append( f1_score(author_predictions['true'], author_predictions['pred_hard'], average = 'macro') )
    
    print("Results with split " + str(split + 1) + ":\n")
    print("soft voting:\n", report['soft'], '\n')
    print("hard voting:\n", report['hard'])


    # get predictions with Logistic Regression----------------------------

    resultsTrain = trainer.predict(Train, ignore_keys = ignore_keys)
    author_predictions_LR = compute_author_predictions_nli_LR(Train, baseTest, resultsTrain.predictions, results.predictions, task, len(class_dict))
    
    f1s_soft_LR.append( f1_score(author_predictions_LR['true'], author_predictions_LR['pred_soft'], average = 'macro') )
    f1s_hard_LR.append( f1_score(author_predictions_LR['true'], author_predictions_LR['pred_hard'], average = 'macro') )
    
    # report metrics 

    report_LR = {'soft': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_soft'], digits=4), 
               'hard': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_hard'], digits=4)}

    print("Results with split " + str(split + 1) + " using LOGISTIC REGRESSION:\n")
    print("soft voting:\n", report_LR['soft'], '\n')
    print("hard voting:\n", report_LR['hard'])

     
    
    # save predictions ----------------------------------------------------
    
    DIR = 'results/' + _DATASET_ + '/' + _LANGUAGE_ + '/' + _PRED_DIR_ + '/' + str(_NUM_AUTHORS_) + '_authors/test_split_' + str(split + 1) + '/'
    if not os.path.exists(DIR):
        os.makedirs(DIR)

    with open(DIR + 'predictions.pickle', 'wb') as f:
        pickle.dump(author_predictions, f)
    
    with open(DIR + 'predictions_LR.pickle', 'wb') as f:
        pickle.dump(author_predictions_LR, f)

    with open(DIR + 'report.txt', 'w') as f:
        f.write("soft voting:\n" + report['soft'] + '\n\n')
        f.write("hard voting:\n" + report['hard'])
        
    with open(DIR + 'report_LR.txt', 'w') as f:
        f.write("soft voting:\n" + report_LR['soft'] + '\n\n')
        f.write("hard voting:\n" + report_LR['hard'])

# %%
# report statistics

print('Soft results: ', f1s_soft)
print('\nHard results: ', f1s_hard)

f1s_soft = np.array(f1s_soft)
f1s_hard = np.array(f1s_hard)

FewShot_Results = {'soft': [f1s_soft.mean(), f1s_soft.std()], 'hard': [f1s_hard.mean(), f1s_hard.std()]}

print('\n\nSoft statistics: ')
print('\t[avg, std]:', FewShot_Results['soft'])

print('\nHard statistics: ')
print('\t[avg, std]:', FewShot_Results['hard'])
# Out:
# Soft results:  [0.87772464 0.87874201 0.87538925 0.87311028 0.88056244]
#
# Hard results:  [0.87085156 0.87190002 0.87020979 0.86672474 0.87427167]
#
#
# Soft statistics:
# 	[avg, std]: [0.8771057226587893, 0.0026045799555797105]
#
# Hard statistics:
# 	[avg, std]: [0.8707915539672667, 0.002458492195639212]

# %%
# report statistics

print('Soft results: ', f1s_soft_LR)
print('\nHard results: ', f1s_hard_LR)

f1s_soft_LR = np.array(f1s_soft_LR)
f1s_hard_LR = np.array(f1s_hard_LR)

FewShot_Results_LR = {'soft': [f1s_soft_LR.mean(), f1s_soft_LR.std()], 'hard': [f1s_hard_LR.mean(), f1s_hard_LR.std()]}

print('\n\nSoft statistics with LOGISTIC REGRESSION: ')
print('\t[avg, std]:', FewShot_Results_LR['soft'])

print('\nHard statistics with LOGISTIC REGRESSION: ')
print('\t[avg, std]:', FewShot_Results_LR['hard'])
# Out:
# Soft results:  [0.89387942 0.89329065 0.88996944 0.89108476 0.89276821]
#
# Hard results:  [0.88545996 0.89092676 0.88429817 0.88428888 0.8921102 ]
#
#
# Soft statistics with LOGISTIC REGRESSION:
# 	[avg, std]: [0.8921984956043228, 0.0014527228167052842]
#
# Hard statistics with LOGISTIC REGRESSION:
# 	[avg, std]: [0.8874167966109849, 0.0033966693523083944]

# %% [markdown]
# ## Training with all

# %%
from tools.DataLoaders import DatasetPANnli

baseTest.get_all_data(_TWEET_BATCH_SIZE_, tokenizer, _MAX_SEQ_LEN_, _PREPROCESS_TEXT_, NLI=True, label_hyp=label_hyp, nli_label2id=nli_label2id)

Test  = DatasetPANnli(baseTest)
Train = DatasetPANnli(baseTrain)
# Out:
# Reading data...
#     Done
# Preprocessing text...
#     Done
# Tokenizing...
#     Done
# Merging data...
#     Done
#
# Total Instances: 96000

# %%
from transformers import TrainingArguments

samples = 4 * _NUM_AUTHORS_ * int(100 / _TWEET_BATCH_SIZE_)
_LOGGING_STEPS_ = int(samples / _BATCH_SIZE_)

training_args = TrainingArguments(
    learning_rate               = _LEARNING_RATE_,
    num_train_epochs            = _EPOCHS_,
    per_device_train_batch_size = _BATCH_SIZE_,
    per_device_eval_batch_size  = 200,
    logging_steps               = _LOGGING_STEPS_,
    output_dir                  = _OUTPUT_DIR_,
    save_total_limit            = 5,
    overwrite_output_dir        = True,
    remove_unused_columns       = False,
)

# %%
from transformers import AutoAdapterModel, AutoModelForSequenceClassification
from tools.DataLoaders import DatasetCrossValnli
from transformers import AdapterTrainer
from tools.Testing import compute_author_predictions_nli, compute_author_predictions_nli_LR
from sklearn.metrics import f1_score, classification_report
import pickle


# train

task = label_name

# initialize model ---------------------------------------------------

static_head_model = AutoModelForSequenceClassification.from_pretrained(_PRETRAINED_LM_)
static_head_model.add_adapter(task, config = _ADAPTER_CONFIG_) 
static_head_model.save_adapter('aux_adapter_'+_PRED_DIR_, task)

model = AutoAdapterModel.from_pretrained(_PRETRAINED_LM_)
model.load_adapter('aux_adapter_'+_PRED_DIR_, load_as=task)
#model.load_adapter('pretrained_adapter_NLI', load_as=task)

model.set_active_adapters(task)
model.train_adapter(task)


# create trainer and train -------------------------------------------

trainer = AdapterTrainer(
    model           = model,
    args            = training_args,
    train_dataset   = Train,
)
trainer.args._n_gpu = _NO_GPUS_

trainer.train()


# get predictions ----------------------------------------------------


ignore_keys = None
if is_encoder_decoder:
    ignore_keys = ['encoder_last_hidden_state']

results            = trainer.predict(Test , ignore_keys = ignore_keys)
author_predictions = compute_author_predictions_nli(baseTest, results.predictions, task, len(class_dict), nli_label2id)

# report metrics 

report = {'soft': classification_report(author_predictions['true'], author_predictions['pred_soft'], digits=4), 
           'hard': classification_report(author_predictions['true'], author_predictions['pred_hard'], digits=4)}

print("Results:\n")
print("soft voting:\n", report['soft'], '\n')
print("hard voting:\n", report['hard'])


# get predictions with Logistic Regression----------------------------


resultsTrain = trainer.predict(Train, ignore_keys = ignore_keys)
author_predictions_LR = compute_author_predictions_nli_LR(baseTrain, baseTest, resultsTrain.predictions, results.predictions, task, len(class_dict))

# report metrics 

report_LR = {'soft': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_soft'], digits=4), 
           'hard': classification_report(author_predictions_LR['true'], author_predictions_LR['pred_hard'], digits=4)}

print("Results using LOGISTIC REGRESSION:\n")
print("soft voting:\n", report_LR['soft'], '\n')
print("hard voting:\n", report_LR['hard'])
# Out:
# Some weights of the model checkpoint at ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli were not used when initializing BartAdapterModel: ['classification_head.dense.weight', 'classification_head.out_proj.weight', 'classification_head.dense.bias', 'classification_head.out_proj.bias']
# - This IS expected if you are initializing BartAdapterModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BartAdapterModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /001/usuarios/isaac.bribiesca/anaconda3/envs/NLP/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 144000
#   Num Epochs = 10
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 180000
#     <div>
#
#       <progress value='12336' max='180000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 12336/180000 47:16 < 10:42:39, 4.35 it/s, Epoch 0.69/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5120</td>
#       <td>0.744400</td>
#     </tr>
#     <tr>
#       <td>10240</td>
#       <td>0.644100</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-500
# Configuration saved in checkPointsIA3NLI/checkpoint-500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-178000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-1000
# Configuration saved in checkPointsIA3NLI/checkpoint-1000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-1000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-1000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-1000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-1000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-1000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-178500] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-1500
# Configuration saved in checkPointsIA3NLI/checkpoint-1500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-1500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-1500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-1500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-1500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-1500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-179000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-2000
# Configuration saved in checkPointsIA3NLI/checkpoint-2000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-2000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-2000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-2000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-2000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-2000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-179500] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-2500
# Configuration saved in checkPointsIA3NLI/checkpoint-2500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-2500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-2500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-2500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-2500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-2500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-180000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-3000
# Configuration saved in checkPointsIA3NLI/checkpoint-3000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-3000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-3000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-3000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-3000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-3000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-3500
# Configuration saved in checkPointsIA3NLI/checkpoint-3500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-3500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-3500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-3500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-3500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-3500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-4000
# Configuration saved in checkPointsIA3NLI/checkpoint-4000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-4000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-4000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-4000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-4000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-4000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-4500
# Configuration saved in checkPointsIA3NLI/checkpoint-4500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-4500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-4500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-4500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-4500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-4500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-5000
# Configuration saved in checkPointsIA3NLI/checkpoint-5000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-5000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-5000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-5000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-5000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-5000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-5500
# Configuration saved in checkPointsIA3NLI/checkpoint-5500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-5500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-5500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-5500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-5500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-5500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-6000
# Configuration saved in checkPointsIA3NLI/checkpoint-6000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-6000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-6000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-6000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-6000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-6000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-6500
# Configuration saved in checkPointsIA3NLI/checkpoint-6500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-6500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-6500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-6500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-6500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-6500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-7000
# Configuration saved in checkPointsIA3NLI/checkpoint-7000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-7000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-7000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-7000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-7000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-7000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-7500
# Configuration saved in checkPointsIA3NLI/checkpoint-7500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-7500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-7500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-7500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-7500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-7500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-8000
# Configuration saved in checkPointsIA3NLI/checkpoint-8000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-8000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-8000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-8000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-8000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-8000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-5500] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-8500
# Configuration saved in checkPointsIA3NLI/checkpoint-8500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-8500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-8500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-8500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-8500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-8500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-9000
# Configuration saved in checkPointsIA3NLI/checkpoint-9000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-9000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-9000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-9000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-9000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-9000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-9500
# Configuration saved in checkPointsIA3NLI/checkpoint-9500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-9500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-9500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-9500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-9500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-9500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-10000
# Configuration saved in checkPointsIA3NLI/checkpoint-10000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-10000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-10000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-10000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-10000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-10000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-10500
# Configuration saved in checkPointsIA3NLI/checkpoint-10500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-10500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-10500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-10500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-10500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-10500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-11000
# Configuration saved in checkPointsIA3NLI/checkpoint-11000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-11000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-11000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-11000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-11000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-11000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-8500] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-11500
# Configuration saved in checkPointsIA3NLI/checkpoint-11500/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-11500/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-11500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-11500/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-11500/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-11500/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to checkPointsIA3NLI/checkpoint-12000
# Configuration saved in checkPointsIA3NLI/checkpoint-12000/gender/adapter_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-12000/gender/pytorch_adapter.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-12000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-12000/gender/pytorch_model_head.bin
# Configuration saved in checkPointsIA3NLI/checkpoint-12000/gender/head_config.json
# Module weights saved in checkPointsIA3NLI/checkpoint-12000/gender/pytorch_model_head.bin
# Deleting older checkpoint [checkPointsIA3NLI/checkpoint-9500] due to args.save_total_limit

# %%
print("Results:\n")
print("soft voting:\n", report['soft'], '\n')
print("hard voting:\n", report['hard'])
# Out:
# Results:
#
# soft voting:
#                precision    recall  f1-score   support
#
#            0     0.7790    0.8283    0.8029      1200
#            1     0.8167    0.7650    0.7900      1200
#
#     accuracy                         0.7967      2400
#    macro avg     0.7979    0.7967    0.7965      2400
# weighted avg     0.7979    0.7967    0.7965      2400
#
#
# hard voting:
#                precision    recall  f1-score   support
#
#            0     0.7693    0.8367    0.8016      1200
#            1     0.8210    0.7492    0.7834      1200
#
#     accuracy                         0.7929      2400
#    macro avg     0.7952    0.7929    0.7925      2400
# weighted avg     0.7952    0.7929    0.7925      2400

# %%
print("Results using LOGISTIC REGRESSION:\n")
print("soft voting:\n", report_LR['soft'], '\n')
print("hard voting:\n", report_LR['hard'])
# Out:
# Results using LOGISTIC REGRESSION:
#
# soft voting:
#                precision    recall  f1-score   support
#
#            0     0.7939    0.8025    0.7982      1200
#            1     0.8003    0.7917    0.7960      1200
#
#     accuracy                         0.7971      2400
#    macro avg     0.7971    0.7971    0.7971      2400
# weighted avg     0.7971    0.7971    0.7971      2400
#
#
# hard voting:
#                precision    recall  f1-score   support
#
#            0     0.7779    0.8200    0.7984      1200
#            1     0.8097    0.7658    0.7872      1200
#
#     accuracy                         0.7929      2400
#    macro avg     0.7938    0.7929    0.7928      2400
# weighted avg     0.7938    0.7929    0.7928      2400

# %%
model.save_adapter('Pretrained_Adapters_NLI/'+_DATASET_+'_'+_PRED_DIR_, task)
